# %%
import pandas as pd
import os
from pathlib import Path
from News_Reccomendation_System.utils.common import load_json
from box import ConfigBox

# %%
# %pwd
# Out:
# '/home/swaraj/PROJECTS/Mews-Reccomendation-System'

# %%
os.chdir('../')

# %%
tr = pd.read_csv('artifacts/data_transformation/train.tsv', sep='\t')
val = pd.read_csv('artifacts/data_transformation/valid.tsv', sep='\t')

# %%
df = pd.concat( [tr, val], ignore_index= True)
del tr, val
df
# Out:
#         epochhrs  userIdx                                  click_history_idx  \
# 0       437073.0        1  [6893, 10050, 15556, 21467, 26358, 4946, 14071...
# 1       437106.0        2  [25816, 2334, 8524, 12087, 13463, 14202, 12733...
# 2       437143.0        3  [5477, 4207, 11684, 7704, 8124, 23394, 22970, ...
# 3       437069.0        4  [13827, 19085, 28506, 7024, 22910, 16667, 1559...
# 4       437104.0        5                        [23643, 4853, 27686, 31189]
# ...          ...      ...                                                ...
# 156960  437148.0     4554  [22289, 11026, 6851, 14472, 24265, 1166, 7691,...
# 156961  437152.0    50000                              [22941, 25895, 29202]
# 156962  437158.0     7282  [21178, 19891, 2656, 14202, 16230, 21717, 1626...
# 156963  437147.0     4834  [19161, 26886, 30517, 27148, 22579, 9315, 1336...
# 156964  437151.0    13309                                     [18449, 14581]
#
#         noclick  click
# 0         50689  33900
# 1         37405  32187
# 2         39528   5767
# 3         50689  50715
# 4          2006  31475
# ...         ...    ...
# 156960    31290  22968
# 156961    35105  49840
# 156962    36709  39852
# 156963    37872  40345
# 156964    40781  34034
#
# [156965 rows x 5 columns]

# %%
trends= df['click'].value_counts()

# %%
type(var)
# Out:
# pandas.core.series.Series

# %%
var.index
# Out:
# Int64Index([33900, 50689, 41551, 45975, 41553, 50366, 50715, 32603, 41884,
#             39830,
#             ...
#             33631, 19080, 34965, 41534, 37987, 39376, 45700, 41013, 44120,
#             39987],
#            dtype='int64', length=6351)

# %%
list(var.index)
# Out:
# [33900,
#  50689,
#  41551,
#  45975,
#  41553,
#  50366,
#  50715,
#  32603,
#  41884,
#  39830,
#  33276,
#  34600,
#  46822,
#  50471,
#  44370,
#  42880,
#  41617,
#  37364,
#  43694,
#  34635,
#  48698,
#  33650,
#  39533,
#  22968,
#  32675,
#  48034,
#  41946,
#  42377,
#  31749,
#  40781,
#  48442,
#  31222,
#  36660,
#  33378,
#  35167,
#  34170,
#  36286,
#  43871,
#  45454,
#  32961,
#  35590,
#  34378,
#  35579,
#  38078,
#  36645,
#  38863,
#  44548,
#  50465,
#  36333,
#  39065,
#  49350,
#  34671,
#  44674,
#  50961,
#  37718,
#  33376,
#  38338,
#  43039,
#  39271,
#  37405,
#  43131,
#  31348,
#  40457,
#  33356,
#  44041,
#  43907,
#  34287,
#  51152,
#  41306,
#  35307,
#  33399,
#  41296,
#  50022,
#  28461,
#  31705,
#  50986,
#  51245,
#  47096,
#  34429,
#  38254,
#  32187,
#  31886,
#  31290,
#  41089,
#  51200,
#  36033,
#  38537,
#  33324,
#  43459,
#  43868,
#  41265,
#  42167,
#  32185,
#  41506,
#  45772,
#  48160,
#  40107,
#  36609,
#  36240,
#  35347,
#  35691,
#  43760,
#  39220,
#  45348,
#  34112,
#  48,
#  36300,
#  49534,
#  31523,
#  37083,
#  37386,
#  31666,
#  50217,
#  33502,
#  43960,
#  46801,
#  50760,
#  41107,
#  40378,
#  35105,
#  719,
#  34397,
#  39247,
#  37163,
#  41742,
#  50697,
#  37098,
#  340,
#  45359,
#  38600,
#  47533,
#  31710,
#  33175,
#  45568,
#  5119,
#  45328,
#  50072,
#  37243,
#  43854,
#  41848,
#  42475,
#  35185,
#  49077,
#  43179,
#  45133,
#  45027,
#  34898,
#  41509,
#  40270,
#  17280,
#  34185,
#  45366,
#  37610,
#  45370,
#  32689,
#  49152,
#  36687,
#  44803,
#  43801,
#  39989,
#  43669,
#  42942,
#  37302,
#  34437,
#  43357,
#  794,
#  49840,
#  41381,
#  45898,
#  31362,
#  43622,
#  33187,
#  38720,
#  34034,
#  40586,
#  46191,
#  36401,
#  31364,
#  31796,
#  41983,
#  43631,
#  45802,
#  40067,
#  33934,
#  5767,
#  31308,
#  3752,
#  50106,
#  49439,
#  35134,
#  36747,
#  41284,
#  49953,
#  42105,
#  35176,
#  36915,
#  34147,
#  46849,
#  37226,
#  50108,
#  34264,
#  8866,
#  40175,
#  50238,
#  32480,
#  48166,
#  37722,
#  42004,
#  41267,
#  48126,
#  36147,
#  35287,
#  34007,
#  50482,
#  45630,
#  36625,
#  50329,
#  40329,
#  36637,
#  42502,
#  38971,
#  41068,
#  31542,
#  44901,
#  43529,
#  36569,
#  4168,
#  5828,
#  42050,
#  45681,
#  16140,
#  51149,
#  37266,
#  21976,
#  371,
#  39333,
#  47958,
#  32661,
#  32212,
#  41814,
#  32434,
#  32825,
#  43063,
#  46758,
#  45395,
#  33481,
#  47727,
#  36167,
#  36461,
#  113,
#  39967,
#  37445,
#  37452,
#  6342,
#  46628,
#  47503,
#  50460,
#  44303,
#  47362,
#  47145,
#  38677,
#  41495,
#  16766,
#  8352,
#  43767,
#  35728,
#  50662,
#  47282,
#  37979,
#  37027,
#  30673,
#  34596,
#  37582,
#  42838,
#  4918,
#  5764,
#  34907,
#  31956,
#  45450,
#  33902,
#  45919,
#  44542,
#  51087,
#  33053,
#  36050,
#  47804,
#  27556,
#  32301,
#  38061,
#  35015,
#  629,
#  18256,
#  7857,
#  42760,
#  48184,
#  37442,
#  28834,
#  42369,
#  37616,
#  50066,
#  33952,
#  1225,
#  48415,
#  37653,
#  45456,
#  43749,
#  40454,
#  45728,
#  13506,
#  43900,
#  34262,
#  40052,
#  49917,
#  47355,
#  765,
#  45661,
#  45721,
#  38140,
#  32336,
#  31324,
#  24781,
#  2175,
#  36054,
#  38869,
#  49209,
#  32832,
#  50469,
#  6192,
#  45518,
#  47418,
#  36343,
#  50555,
#  45889,
#  31920,
#  31194,
#  150,
#  51263,
#  41703,
#  38498,
#  27812,
#  27965,
#  40520,
#  40499,
#  47529,
#  44815,
#  40365,
#  50056,
#  51015,
#  26775,
#  43450,
#  36499,
#  36808,
#  37545,
#  45911,
#  40893,
#  38669,
#  41554,
#  45765,
#  47454,
#  25542,
#  26025,
#  43109,
#  31404,
#  32971,
#  47062,
#  35749,
#  21616,
#  49558,
#  48554,
#  32161,
#  35165,
#  50768,
#  45458,
#  32032,
#  11809,
#  37533,
#  34350,
#  38166,
#  38908,
#  42526,
#  4339,
#  48256,
#  46382,
#  48201,
#  40120,
#  38733,
#  31857,
#  40914,
#  20629,
#  42718,
#  1010,
#  43171,
#  32498,
#  32052,
#  50030,
#  9933,
#  39954,
#  22009,
#  37955,
#  49493,
#  34210,
#  40145,
#  32766,
#  45809,
#  33572,
#  39557,
#  31191,
#  17646,
#  16309,
#  46103,
#  33321,
#  41286,
#  49295,
#  36755,
#  37306,
#  49040,
#  41782,
#  1500,
#  21859,
#  34921,
#  10730,
#  34021,
#  38174,
#  33872,
#  39375,
#  45807,
#  50515,
#  50221,
#  39992,
#  31648,
#  20114,
#  37034,
#  47449,
#  35527,
#  43679,
#  49406,
#  50603,
#  47666,
#  41692,
#  43567,
#  33250,
#  42175,
#  36671,
#  21698,
#  32148,
#  37518,
#  35848,
#  40908,
#  47138,
#  24586,
#  35084,
#  50171,
#  46032,
#  31196,
#  36793,
#  31244,
#  49429,
#  50371,
#  46625,
#  49164,
#  42260,
#  50835,
#  32331,
#  43092,
#  40606,
#  50129,
#  32719,
#  13625,
#  6711,
#  42730,
#  39141,
#  17464,
#  5095,
#  49641,
#  51118,
#  42252,
#  1620,
#  41433,
#  31100,
#  32191,
#  50248,
#  33787,
#  43647,
#  34298,
#  5096,
#  49676,
#  41451,
#  16575,
#  44725,
#  41004,
#  34314,
#  22537,
#  32001,
#  42857,
#  43538,
#  42123,
#  12497,
#  36195,
#  33403,
#  38897,
#  44751,
#  40193,
#  32739,
#  33133,
#  49716,
#  51216,
#  42121,
#  35058,
#  50606,
#  49258,
#  35102,
#  37139,
#  3974,
#  39965,
#  25896,
#  31522,
#  32144,
#  40733,
#  33548,
#  45584,
#  39356,
#  43031,
#  49125,
#  39151,
#  40143,
#  42697,
#  37025,
#  40734,
#  2705,
#  37248,
#  41586,
#  458,
#  32931,
#  49167,
#  45735,
#  51275,
#  5680,
#  42649,
#  47527,
#  38983,
#  41327,
#  38493,
#  46184,
#  50434,
#  2504,
#  33309,
#  41920,
#  37210,
#  32111,
#  39338,
#  46036,
#  51042,
#  32643,
#  34797,
#  33911,
#  39305,
#  42503,
#  31541,
#  41943,
#  38758,
#  32170,
#  3997,
#  36503,
#  51161,
#  31310,
#  42801,
#  36650,
#  43811,
#  33407,
#  49583,
#  9279,
#  34082,
#  50740,
#  37929,
#  32764,
#  47383,
#  18781,
#  48388,
#  49965,
#  43239,
#  39290,
#  33282,
#  35879,
#  26687,
#  38108,
#  3292,
#  48629,
#  4764,
#  36437,
#  34491,
#  43600,
#  33420,
#  24238,
#  45073,
#  40215,
#  41161,
#  40774,
#  50830,
#  37827,
#  16034,
#  42220,
#  39339,
#  46070,
#  39026,
#  32363,
#  32133,
#  49660,
#  35897,
#  3254,
#  49099,
#  41486,
#  43708,
#  33697,
#  34359,
#  49500,
#  40812,
#  48969,
#  33555,
#  42687,
#  50278,
#  47984,
#  42113,
#  34960,
#  41094,
#  41796,
#  42014,
#  33266,
#  39211,
#  33951,
#  32016,
#  37297,
#  40530,
#  44862,
#  33185,
#  40473,
#  42452,
#  46722,
#  35905,
#  37664,
#  3083,
#  47265,
#  28751,
#  36873,
#  42937,
#  49619,
#  50260,
#  46217,
#  38997,
#  40231,
#  36105,
#  46680,
#  42312,
#  40219,
#  36858,
#  49489,
#  27901,
#  48408,
#  40807,
#  41996,
#  48328,
#  32550,
#  49804,
#  664,
#  48283,
#  43477,
#  38886,
#  46978,
#  32623,
#  47201,
#  35252,
#  48293,
#  35840,
#  37185,
#  7409,
#  40059,
#  42806,
#  50827,
#  50907,
#  38833,
#  35720,
#  35677,
#  37538,
#  41282,
#  42759,
#  31479,
#  33663,
#  51001,
#  32063,
#  44201,
#  41192,
#  36308,
#  31635,
#  36197,
#  43010,
#  22852,
#  28,
#  45558,
#  31917,
#  41917,
#  51271,
#  50351,
#  2567,
#  46951,
#  43940,
#  43743,
#  37356,
#  47548,
#  47250,
#  32043,
#  41349,
#  36783,
#  31672,
#  41342,
#  33418,
#  49905,
#  37394,
#  37848,
#  46061,
#  32504,
#  43557,
#  49076,
#  40095,
#  6590,
#  31383,
#  37214,
#  33362,
#  33341,
#  43062,
#  35417,
#  39058,
#  31791,
#  47695,
#  27496,
#  31949,
#  38621,
#  35957,
#  40917,
#  2665,
#  46799,
#  44735,
#  48057,
#  46371,
#  2462,
#  20302,
#  49597,
#  34285,
#  45291,
#  1198,
#  11780,
#  13360,
#  39712,
#  37872,
#  42235,
#  34513,
#  37108,
#  35462,
#  47052,
#  40858,
#  38773,
#  43872,
#  48450,
#  43510,
#  38512,
#  32097,
#  32954,
#  32242,
#  40353,
#  39138,
#  44759,
#  47954,
#  47835,
#  33328,
#  1935,
#  47484,
#  41660,
#  34165,
#  11493,
#  34747,
#  18797,
#  48399,
#  36656,
#  39640,
#  46600,
#  34884,
#  36757,
#  17293,
#  49073,
#  42766,
#  47646,
#  45481,
#  36972,
#  39604,
#  50194,
#  43374,
#  38964,
#  39852,
#  39645,
#  36110,
#  42173,
#  41932,
#  45103,
#  35661,
#  39442,
#  40382,
#  43712,
#  50640,
#  31475,
#  36277,
#  37662,
#  49506,
#  45090,
#  40641,
#  51269,
#  43097,
#  50409,
#  3357,
#  47050,
#  30241,
#  35662,
#  48748,
#  38313,
#  31573,
#  33894,
#  44263,
#  38104,
#  36906,
#  5486,
#  47942,
#  28034,
#  49454,
#  38975,
#  32358,
#  32717,
#  39393,
#  34080,
#  48455,
#  44354,
#  45110,
#  39268,
#  39027,
#  51126,
#  27510,
#  36072,
#  34441,
#  36145,
#  41084,
#  34946,
#  46510,
#  39513,
#  41075,
#  3200,
#  43081,
#  16636,
#  39716,
#  43635,
#  40345,
#  13017,
#  48582,
#  45960,
#  50488,
#  46137,
#  47207,
#  34256,
#  35554,
#  15413,
#  34303,
#  3104,
#  42396,
#  12325,
#  40013,
#  46505,
#  42313,
#  38256,
#  42387,
#  41082,
#  46527,
#  50610,
#  39778,
#  50677,
#  38162,
#  6802,
#  47950,
#  47053,
#  47019,
#  31773,
#  28568,
#  40899,
#  50231,
#  50336,
#  48345,
#  46652,
#  38384,
#  36869,
#  38518,
#  51249,
#  38611,
#  34538,
#  48418,
#  35688,
#  41641,
#  31516,
#  4772,
#  45573,
#  34024,
#  44903,
#  35582,
#  31839,
#  49435,
#  47876,
#  27090,
#  31708,
#  3549,
#  41600,
#  35391,
#  1117,
#  7631,
#  34382,
#  31177,
#  48353,
#  33458,
#  49384,
#  43492,
#  42439,
#  46800,
#  47565,
#  36754,
#  50691,
#  42339,
#  31416,
#  8111,
#  44741,
#  50604,
#  49156,
#  44478,
#  50653,
#  31176,
#  50903,
#  44832,
#  43079,
#  37023,
#  48968,
#  31385,
#  6251,
#  48326,
#  35933,
#  35689,
#  34313,
#  38978,
#  15446,
#  24249,
#  36836,
#  33817,
#  45722,
#  18521,
#  49128,
#  49679,
#  50350,
#  38747,
#  23856,
#  33235,
#  49497,
#  33169,
#  51038,
#  43599,
#  40458,
#  33708,
#  24136,
#  46572,
#  43266,
#  39647,
#  44016,
#  43705,
#  32320,
#  41812,
#  37136,
#  42599,
#  40691,
#  43597,
#  46445,
#  39528,
#  31880,
#  38517,
#  49383,
#  48960,
#  38009,
#  25418,
#  47874,
#  32227,
#  40401,
#  575,
#  32975,
#  49882,
#  31987,
#  45144,
#  32370,
#  44128,
#  37205,
#  42735,
#  31879,
#  16126,
#  ...]

# %%
var.sort_values(ascending=False)
# Out:
# 33900    3662
# 50689    2638
# 41551    2464
# 45975    2360
# 41553    2021
#          ...
# 40796       1
# 13451       1
# 42750       1
# 50613       1
# 39987       1
# Name: click, Length: 6351, dtype: int64

# %%
news = pd.read_csv('artifacts/data_ingestion/news.tsv', sep='\t', names=["itemId",
                                "category",
                                "subcategory",
                                "title","abstract",
                                "url",
                                "title_entities",
                                "abstract_entities"])

# %%
js = load_json(Path('artifacts/data_transformation/item2ind.json'))
# Out:
# [2023-12-05 01:15:38,695: INFO: common: JSON file loaded succesfully from: artifacts/data_transformation/item2ind.json]

# %%
news
# Out:
#        itemId   category        subcategory  \
# 0      N55528  lifestyle    lifestyleroyals
# 1      N19639     health         weightloss
# 2      N61837       news          newsworld
# 3      N53526     health             voices
# 4      N38324     health            medical
# ...       ...        ...                ...
# 51277  N16909    weather  weathertopstories
# 51278  N47585  lifestyle    lifestylefamily
# 51279   N7482     sports        more_sports
# 51280  N34418     sports         soccer_epl
# 51281  N44276      autos        autossports
#
#                                                    title  \
# 0      The Brands Queen Elizabeth, Prince Charles, an...
# 1                          50 Worst Habits For Belly Fat
# 2      The Cost of Trump's Aid Freeze in the Trenches...
# 3      I Was An NBA Wife. Here's How It Affected My M...
# 4      How to Get Rid of Skin Tags, According to a De...
# ...                                                  ...
# 51277  Adapting, Learning And Soul Searching: Reflect...
# 51278  Family says 13-year-old Broadway star died fro...
# 51279  St. Dominic soccer player tries to kick cancer...
# 51280                       How the Sounders won MLS Cup
# 51281                  Best Sports Car Deals for October
#
#                                                 abstract  \
# 0      Shop the notebooks, jackets, and more that the...
# 1      These seemingly harmless habits are holding yo...
# 2      Lt. Ivan Molchanets peeked over a parapet of s...
# 3      I felt like I was a fraud, and being an NBA wi...
# 4      They seem harmless, but there's a very good re...
# ...                                                  ...
# 51277  Woolsey Fire Anniversary: A community is forev...
# 51278                                                NaN
# 51279  Sometimes, what happens on the sidelines can b...
# 51280  Mark, Jeremiah and Casey were so excited they ...
# 51281                                                NaN
#
#                                                  url  \
# 0      https://assets.msn.com/labs/mind/AAGH0ET.html
# 1      https://assets.msn.com/labs/mind/AAB19MK.html
# 2      https://assets.msn.com/labs/mind/AAJgNsz.html
# 3      https://assets.msn.com/labs/mind/AACk2N6.html
# 4      https://assets.msn.com/labs/mind/AAAKEkt.html
# ...                                              ...
# 51277  https://assets.msn.com/labs/mind/BBWzQJK.html
# 51278  https://assets.msn.com/labs/mind/BBWzQYV.html
# 51279  https://assets.msn.com/labs/mind/BBWzQnK.html
# 51280  https://assets.msn.com/labs/mind/BBWzQuK.html
# 51281  https://assets.msn.com/labs/mind/BBy5rVe.html
#
#                                           title_entities  \
# 0      [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1      [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 2                                                     []
# 3                                                     []
# 4      [{"Label": "Skin tag", "Type": "C", "WikidataI...
# ...                                                  ...
# 51277  [{"Label": "Woolsey Fire", "Type": "N", "Wikid...
# 51278  [{"Label": "Broadway theatre", "Type": "F", "W...
# 51279                                                 []
# 51280  [{"Label": "MLS Cup", "Type": "U", "WikidataId...
# 51281  [{"Label": "Peugeot RCZ", "Type": "V", "Wikida...
#
#                                        abstract_entities
# 0                                                     []
# 1      [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 2      [{"Label": "Ukraine", "Type": "G", "WikidataId...
# 3      [{"Label": "National Basketball Association", ...
# 4      [{"Label": "Skin tag", "Type": "C", "WikidataI...
# ...                                                  ...
# 51277  [{"Label": "Woolsey Fire", "Type": "N", "Wikid...
# 51278                                                 []
# 51279                                                 []
# 51280                                                 []
# 51281                                                 []
#
# [51282 rows x 8 columns]

# %%
news['news_id'] = news.itemId.apply(lambda x: js[x])

# %%
news
# Out:
#        itemId   category        subcategory  \
# 0      N55528  lifestyle    lifestyleroyals
# 1      N19639     health         weightloss
# 2      N61837       news          newsworld
# 3      N53526     health             voices
# 4      N38324     health            medical
# ...       ...        ...                ...
# 51277  N16909    weather  weathertopstories
# 51278  N47585  lifestyle    lifestylefamily
# 51279   N7482     sports        more_sports
# 51280  N34418     sports         soccer_epl
# 51281  N44276      autos        autossports
#
#                                                    title  \
# 0      The Brands Queen Elizabeth, Prince Charles, an...
# 1                          50 Worst Habits For Belly Fat
# 2      The Cost of Trump's Aid Freeze in the Trenches...
# 3      I Was An NBA Wife. Here's How It Affected My M...
# 4      How to Get Rid of Skin Tags, According to a De...
# ...                                                  ...
# 51277  Adapting, Learning And Soul Searching: Reflect...
# 51278  Family says 13-year-old Broadway star died fro...
# 51279  St. Dominic soccer player tries to kick cancer...
# 51280                       How the Sounders won MLS Cup
# 51281                  Best Sports Car Deals for October
#
#                                                 abstract  \
# 0      Shop the notebooks, jackets, and more that the...
# 1      These seemingly harmless habits are holding yo...
# 2      Lt. Ivan Molchanets peeked over a parapet of s...
# 3      I felt like I was a fraud, and being an NBA wi...
# 4      They seem harmless, but there's a very good re...
# ...                                                  ...
# 51277  Woolsey Fire Anniversary: A community is forev...
# 51278                                                NaN
# 51279  Sometimes, what happens on the sidelines can b...
# 51280  Mark, Jeremiah and Casey were so excited they ...
# 51281                                                NaN
#
#                                                  url  \
# 0      https://assets.msn.com/labs/mind/AAGH0ET.html
# 1      https://assets.msn.com/labs/mind/AAB19MK.html
# 2      https://assets.msn.com/labs/mind/AAJgNsz.html
# 3      https://assets.msn.com/labs/mind/AACk2N6.html
# 4      https://assets.msn.com/labs/mind/AAAKEkt.html
# ...                                              ...
# 51277  https://assets.msn.com/labs/mind/BBWzQJK.html
# 51278  https://assets.msn.com/labs/mind/BBWzQYV.html
# 51279  https://assets.msn.com/labs/mind/BBWzQnK.html
# 51280  https://assets.msn.com/labs/mind/BBWzQuK.html
# 51281  https://assets.msn.com/labs/mind/BBy5rVe.html
#
#                                           title_entities  \
# 0      [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1      [{"Label": "Adipose tissue", "Type": "C", "Wik...
# 2                                                     []
# 3                                                     []
# 4      [{"Label": "Skin tag", "Type": "C", "WikidataI...
# ...                                                  ...
# 51277  [{"Label": "Woolsey Fire", "Type": "N", "Wikid...
# 51278  [{"Label": "Broadway theatre", "Type": "F", "W...
# 51279                                                 []
# 51280  [{"Label": "MLS Cup", "Type": "U", "WikidataId...
# 51281  [{"Label": "Peugeot RCZ", "Type": "V", "Wikida...
#
#                                        abstract_entities  news_id
# 0                                                     []        1
# 1      [{"Label": "Adipose tissue", "Type": "C", "Wik...        2
# 2      [{"Label": "Ukraine", "Type": "G", "WikidataId...        3
# 3      [{"Label": "National Basketball Association", ...        4
# 4      [{"Label": "Skin tag", "Type": "C", "WikidataI...        5
# ...                                                  ...      ...
# 51277  [{"Label": "Woolsey Fire", "Type": "N", "Wikid...    51278
# 51278                                                 []    51279
# 51279                                                 []    51280
# 51280                                                 []    51281
# 51281                                                 []    51282
#
# [51282 rows x 9 columns]

# %%
dd = news[news['news_id'].isin(var.index)]
dd
# Out:
#        itemId      category         subcategory  \
# 12     N39758        health           nutrition
# 27     N59469     lifestyle     lifestyleroyals
# 47     N41387            tv          tv-gallery
# 74     N16104  foodanddrink  restaurantsandnews
# 85     N60852       weather   weathertopstories
# ...       ...           ...                 ...
# 51262  N41222          news           newsworld
# 51268   N5497          news              newsus
# 51270   N6379          news           newscrime
# 51274  N43432          news              newsus
# 51276  N23858        sports                golf
#
#                                                    title  \
# 12     25 Biggest Grocery Store Mistakes Making You G...
# 27            Every outfit Duchess Kate has worn in 2019
# 47     Can you answer these real Jeopardy questions a...
# 74           The Top 50 Fast Food Restaurants in America
# 85                  In Photos: Flooding across the globe
# ...                                                  ...
# 51262    Evo Morales of Bolivia Accepts Asylum in Mexico
# 51268  Still teaching at 95, Jimmy Carter draws devot...
# 51270  California cops respond to 2 homeless men shot...
# 51274  US Forest Service shuts down vandalized Georgi...
# 51276  Young Northeast Florida fans flock to U.S. wom...
#
#                                                 abstract  \
# 12     From picking up free goodies to navigating the...
# 27     See Kate Middleton's style choices this year f...
# 47     Culling data straight from the "Jeopardy!" arc...
# 74     Find out how your favorite fast food joint sta...
# 85     Millions of people have been displaced from th...
# ...                                                  ...
# 51262  Evo Morales, the former president of Bolivia w...
# 51268  PLAINS, Ga. (AP)   The pilgrims arrive early a...
# 51270  Two homeless men living at an encampment near ...
# 51274  GAINESVILLE, Ga. (AP)   The U.S. Forest Servic...
# 51276  When the U.S. women's national soccer team arr...
#
#                                                  url  \
# 12     https://assets.msn.com/labs/mind/AABqkFQ.html
# 27     https://assets.msn.com/labs/mind/AABvaDh.html
# 47     https://assets.msn.com/labs/mind/AABs6Gq.html
# 74     https://assets.msn.com/labs/mind/AACJNCJ.html
# 85     https://assets.msn.com/labs/mind/AAEmMJu.html
# ...                                              ...
# 51262  https://assets.msn.com/labs/mind/BBWzAVm.html
# 51268  https://assets.msn.com/labs/mind/BBWzBrF.html
# 51270  https://assets.msn.com/labs/mind/BBWzCZq.html
# 51274  https://assets.msn.com/labs/mind/BBWzDfU.html
# 51276  https://assets.msn.com/labs/mind/BBWzQB8.html
#
#                                           title_entities  \
# 12     [{"Label": "Weight gain", "Type": "C", "Wikida...
# 27                                                    []
# 47     [{"Label": "Jeopardy!", "Type": "W", "Wikidata...
# 74     [{"Label": "Fast food restaurant", "Type": "C"...
# 85                                                    []
# ...                                                  ...
# 51262  [{"Label": "Evo Morales", "Type": "P", "Wikida...
# 51268  [{"Label": "Jimmy Carter", "Type": "P", "Wikid...
# 51270  [{"Label": "California", "Type": "G", "Wikidat...
# 51274  [{"Label": "Georgia (U.S. state)", "Type": "G"...
# 51276  [{"Label": "First Coast", "Type": "G", "Wikida...
#
#                                        abstract_entities  news_id
# 12                                                    []       13
# 27     [{"Label": "Catherine, Duchess of Cambridge", ...       28
# 47     [{"Label": "Jeopardy!", "Type": "W", "Wikidata...       48
# 74                                                    []       75
# 85                                                    []       86
# ...                                                  ...      ...
# 51262  [{"Label": "Evo Morales", "Type": "P", "Wikida...    51263
# 51268  [{"Label": "Jimmy Carter", "Type": "P", "Wikid...    51269
# 51270  [{"Label": "San Francisco", "Type": "G", "Wiki...    51271
# 51274  [{"Label": "Georgia (U.S. state)", "Type": "G"...    51275
# 51276  [{"Label": "United States women's national soc...    51277
#
# [6351 rows x 9 columns]

# %%
d = dd[dd['category']=='health']
d
# Out:
#        itemId category subcategory  \
# 12     N39758   health   nutrition
# 100    N52683   health     fitness
# 370      N732   health   nutrition
# 394    N49375   health   nutrition
# 395    N58574   health      voices
# ...       ...      ...         ...
# 50350    N926   health    wellness
# 50496  N61648   health     medical
# 50720  N16016   health  healthnews
# 50783   N4396   health     medical
# 50924  N28170   health     medical
#
#                                                    title  \
# 12     25 Biggest Grocery Store Mistakes Making You G...
# 100    14 Celebs Over 50 Who Are In The Best Shape Of...
# 370    105 Most Popular Sodas Ranked by How Toxic The...
# 394                              Is Lemon Water Healthy?
# 395    I Was 24 & Had Just Scored My Dream Job In Fas...
# ...                                                  ...
# 50350              What Menopause Does to Women's Brains
# 50496   13 Unexpected Reasons Why You Might Have A Fever
# 50720  More than 130,000 pounds of ground beef recall...
# 50783  New CA Hospital Safety Ratings Released: 2 Get...
# 50924       Virginia, DC Hospital Safety Grades For 2019
#
#                                                 abstract  \
# 12     From picking up free goodies to navigating the...
# 100    A list of celebs over 50 who take health and f...
# 370    From classics like Coke and A&W to cult favori...
# 394    Is lemon water really as healthy as people cla...
# 395    One in four adults in the U.S. are living with...
# ...                                                  ...
# 50350  Two-thirds of Alzheimer's patients are women. ...
# 50496  Feeling a little heated? It's typically nothin...
# 50720  About 130,464 pounds of raw ground beef produc...
# 50783  New hospital safety grades for California have...
# 50924  The nonprofit Leapfrog group released its bi-a...
#
#                                                  url  \
# 12     https://assets.msn.com/labs/mind/AABqkFQ.html
# 100    https://assets.msn.com/labs/mind/AABHaIE.html
# 370    https://assets.msn.com/labs/mind/AAF5HQU.html
# 394    https://assets.msn.com/labs/mind/AAE1TNI.html
# 395    https://assets.msn.com/labs/mind/AAGoTDf.html
# ...                                              ...
# 50350  https://assets.msn.com/labs/mind/BBWsRpz.html
# 50496  https://assets.msn.com/labs/mind/BBWyfsu.html
# 50720  https://assets.msn.com/labs/mind/BBWsnTh.html
# 50783  https://assets.msn.com/labs/mind/BBWym6J.html
# 50924  https://assets.msn.com/labs/mind/BBWyqIz.html
#
#                                           title_entities  \
# 12     [{"Label": "Weight gain", "Type": "C", "Wikida...
# 100    [{"Label": "Shape (magazine)", "Type": "M", "W...
# 370                                                   []
# 394                                                   []
# 395    [{"Label": "The Hamptons", "Type": "U", "Wikid...
# ...                                                  ...
# 50350                                                 []
# 50496                                                 []
# 50720  [{"Label": "Ground beef", "Type": "U", "Wikida...
# 50783                                                 []
# 50924  [{"Label": "Virginia", "Type": "G", "WikidataI...
#
#                                        abstract_entities  news_id
# 12                                                    []       13
# 100                                                   []      101
# 370                                                   []      371
# 394                                                   []      395
# 395    [{"Label": "United States", "Type": "G", "Wiki...      396
# ...                                                  ...      ...
# 50350  [{"Label": "Alzheimer's disease", "Type": "U",...    50351
# 50496                                                 []    50497
# 50720  [{"Label": "Ground beef", "Type": "U", "Wikida...    50721
# 50783  [{"Label": "California", "Type": "G", "Wikidat...    50784
# 50924  [{"Label": "Patient safety organization", "Typ...    50925
#
# [311 rows x 9 columns]

# %%
a = d.to_dict('records')

# %%
a = list(map(lambda x: ConfigBox(x), a))

# %%
for i in a:
    print(str(i.title) + str(i.abstract))
    break
# Out:
# 25 Biggest Grocery Store Mistakes Making You Gain WeightFrom picking up free goodies to navigating the wrong aisles, these grocery shopping mistakes could be one of the sneaky reasons you're gaining weight.

# %%
news['full'] = news.apply(lambda row: str(row['title']) + str(row['abstract']), axis=1)

# %%
news[news['news_id']== 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/swaraj/PROJECTS/Mews-Reccomendation-System/Experimentation/step5_trending_news.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/swaraj/PROJECTS/Mews-Reccomendation-System/Experimentation/step5_trending_news.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> news[news['news_id']== 2]
#
# NameError: name 'news' is not defined

# %%
# entity
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class TrendingAPIConfig:
    training_data: Path
    validation_data: Path
    news_data: Path
    col_name: list
    item2ind_json: Path

# %%
# configuration Manager

from News_Reccomendation_System.constants import *
from News_Reccomendation_System.utils.common import read_yaml, create_directories



#  Updating Configuratiom Manager inside src/ config

class ConfigurationManager:                  
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,                     # These were all defined in constants
        params_filepath = PARAMS_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH
    ):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifact_root])

    def get_trending_config(self) -> TrendingAPIConfig:

        config = self.config.trending_api

        trending_api_configuration = TrendingAPIConfig(
            training_data= config.training_data,
            validation_data= config.validation_data,
            news_data= config.news_data,
            col_name= config.col_name,
            item2ind_json= config.item2ind_json
        )

        return trending_api_configuration

# %%
#  Components

class Trending:

    def __init__(self, config: TrendingAPIConfig):
        self.config = config

    def __to_records(self, df: pd.DataFrame):
        records = df.to_dict('records')
        records = list(map(lambda x: ConfigBox(x), records))
        return records

    def get_trending_news(self):
        tr = pd.read_csv(self.config.training_data, sep='\t')
        val = pd.read_csv(self.config.validation_data, sep='\t')
        df = pd.concat( [tr, val], ignore_index= True)
        del tr, val
        trends= df['click'].value_counts()
        trends.sort_values(ascending=False)
        news = pd.read_csv(self.config.news_data, sep='\t', names= self.config.col_name)
        js = load_json(Path(self.config.item2ind_json))
        news['news_id'] = news.itemId.apply(lambda x: js[x])
        self.trending_df = news[news['news_id'].isin(trends.index)]
        trending_records = self.__to_records(df= self.trending_df)

        return trending_records
    
    def get_category_df(self, category: str) -> pd.DataFrame:

        category_df = self.trending_df[self.trending_df['category']==category]
        category_records = self.__to_records(category_df)
        return category_records

# %%
# Pipeline

class TrendingNewsPipeline:
    def __init__(self) -> None:
        pass

    def main(self, category=None):

        config = ConfigurationManager()
        trending_api_configuration = config.get_trending_config()
        trending = Trending(config= trending_api_configuration)
        trending_records = trending.get_trending_news()
        if category:
            category_records = trending.get_category_df(category= category)
            return category_records
        return trending_records

# %%
from News_Reccomendation_System import logger

STEP_NAME = ' ---- Requesting Trending API ---------'


def trending_api(category= None):
    try:
        logger.info(f' >>>>>>> Step {STEP_NAME} started <<<<<<<<<<<')
        obj = TrendingNewsPipeline()
        trends = obj.main(category= category)
        logger.info(f' >>>>>>> Step {STEP_NAME} completed <<<<<<<<<<<\n\nx====================x')
        return trends

    except Exception as e:
            logger.exception(e)
            raise e

# %%
trending_api(category= 'health')
# Out:
# [2023-12-05 03:49:48,403: INFO: 1780285486:  >>>>>>> Step  ---- Requesting Trending API --------- started <<<<<<<<<<<]
# [2023-12-05 03:49:48,434: INFO: common: yaml file: config/config.yaml loaded succesfully]
# [2023-12-05 03:49:48,444: INFO: common: yaml file: params.yaml loaded succesfully]
# [2023-12-05 03:49:48,448: INFO: common: yaml file: schema.yaml loaded succesfully]
# [2023-12-05 03:49:48,450: INFO: common: Created directory at : artifacts]
# [2023-12-05 03:49:50,077: INFO: common: JSON file loaded succesfully from: artifacts/data_transformation/item2ind.json]
# [2023-12-05 03:49:50,591: INFO: 1780285486:  >>>>>>> Step  ---- Requesting Trending API --------- completed <<<<<<<<<<<
#
# x====================x]
# [ConfigBox({'itemId': 'N39758', 'category': 'health', 'subcategory': 'nutrition', 'title': '25 Biggest Grocery Store Mistakes Making You Gain Weight', 'abstract': "From picking up free goodies to navigating the wrong aisles, these grocery shopping mistakes could be one of the sneaky reasons you're gaining weight.", 'url': 'https://assets.msn.com/labs/mind/AABqkFQ.html', 'title_entities': '[{"Label": "Weight gain", "Type": "C", "WikidataId": "Q3403879", "Confidence": 1.0, "OccurrenceOffsets": [45], "SurfaceForms": ["Gain Weight"]}]', 'abstract_entities': '[]', 'news_id': 13}),
#  ConfigBox({'itemId': 'N52683', 'category': 'health', 'subcategory': 'fitness', 'title': '14 Celebs Over 50 Who Are In The Best Shape Of Their Lives', 'abstract': 'A list of celebs over 50 who take health and fitness very seriously   and it shows!', 'url': 'https://assets.msn.com/labs/mind/AABHaIE.html', 'title_entities': '[{"Label": "Shape (magazine)", "Type": "M", "WikidataId": "Q327416", "Confidence": 0.984, "OccurrenceOffsets": [38], "SurfaceForms": ["Shape"]}]', 'abstract_entities': '[]', 'news_id': 101}),
#  ConfigBox({'itemId': 'N732', 'category': 'health', 'subcategory': 'nutrition', 'title': '105 Most Popular Sodas Ranked by How Toxic They Are', 'abstract': 'From classics like Coke and A&W to cult favorites, we reveal which soda is worst for your health.', 'url': 'https://assets.msn.com/labs/mind/AAF5HQU.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 371}),
#  ConfigBox({'itemId': 'N49375', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Is Lemon Water Healthy?', 'abstract': 'Is lemon water really as healthy as people claim it to be? We ask an expert if lemon water is truly the key to achieving optimal health.', 'url': 'https://assets.msn.com/labs/mind/AAE1TNI.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 395}),
#  ConfigBox({'itemId': 'N58574', 'category': 'health', 'subcategory': 'voices', 'title': 'I Was 24 & Had Just Scored My Dream Job In Fashion. Then An Accident In The Hamptons Changed Everything.', 'abstract': "One in four adults in the U.S. are living with a disability, but you wouldn't know it given the lack of representation in media, Hollywood, and the workforce. We're shedding light on the real stories   not the caricatures   of this dynamic and vibrant community of individuals. Read more stories from our Voices of Disability series. By the time I was 24, I was living a life that felt like a dream. I was pursuing a career in the fashion industry,...", 'url': 'https://assets.msn.com/labs/mind/AAGoTDf.html', 'title_entities': '[{"Label": "The Hamptons", "Type": "U", "WikidataId": "Q1574020", "Confidence": 0.989, "OccurrenceOffsets": [76], "SurfaceForms": ["Hamptons"]}]', 'abstract_entities': '[{"Label": "United States", "Type": "G", "WikidataId": "Q30", "Confidence": 0.995, "OccurrenceOffsets": [26], "SurfaceForms": ["U.S."]}]', 'news_id': 396}),
#  ConfigBox({'itemId': 'N34930', 'category': 'health', 'subcategory': 'nutrition', 'title': "9 Vegetables You Shouldn't Eat Raw", 'abstract': 'Are raw foods healthier than cooked foods?', 'url': 'https://assets.msn.com/labs/mind/AACMPka.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 575}),
#  ConfigBox({'itemId': 'N3465', 'category': 'health', 'subcategory': 'voices', 'title': "This Is What It's Like to Give Up Alcohol For a Week", 'abstract': "I don't often examine my drinking, but I was curious about the less obvious effects of alcohol on my life. This is what I learned from a week of sobriety.", 'url': 'https://assets.msn.com/labs/mind/AAGmpeq.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 760}),
#  ConfigBox({'itemId': 'N62920', 'category': 'health', 'subcategory': 'weightloss', 'title': 'This Guy Lost 30 Pounds and Gained a Rock-Hard Six Pack', 'abstract': 'Pizza, Chinese take-out, McDonald\'s, ice cream, you name it   "If it isn\'t good for you, I would enjoy eating it in large quantities," says Chris Anderson.', 'url': 'https://assets.msn.com/labs/mind/AAI4mSg.html', 'title_entities': '[{"Label": "Rock Hard (magazine)", "Type": "M", "WikidataId": "Q455803", "Confidence": 0.99, "OccurrenceOffsets": [37], "SurfaceForms": ["Rock-Hard"]}]', 'abstract_entities': '[{"Label": "McDonald\'s", "Type": "O", "WikidataId": "Q38076", "Confidence": 1.0, "OccurrenceOffsets": [25], "SurfaceForms": ["McDonald\'s"]}]', 'news_id': 1225}),
#  ConfigBox({'itemId': 'N16504', 'category': 'health', 'subcategory': 'wellness', 'title': "Texting Thumb Hurts, and It's Your Valid Excuse to Finally Unplug", 'abstract': 'The number of blue light glasses and tech neck creams on the market have probably clued you in: technology can do some damage to our bodies', 'url': 'https://assets.msn.com/labs/mind/AAJWIqN.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 1340}),
#  ConfigBox({'itemId': 'N12430', 'category': 'health', 'subcategory': 'voices', 'title': "I Kissed Dieting Goodbye, and Finally Lost 20 Pounds. Here's Why.", 'abstract': "When one editor finally decided to stop dieting, her health significantly improved. Here's her story on how she decided to break up with dieting for good.", 'url': 'https://assets.msn.com/labs/mind/AAFqJGx.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 1419}),
#  ConfigBox({'itemId': 'N5886', 'category': 'health', 'subcategory': 'wellness', 'title': 'Daphne Oz Just Shared the Most Relatable Abs Photo 10 Weeks After Giving Birth', 'abstract': 'The 33-year-old host of "Master Chef Junior" shared a super-relatable selfie on Monday.', 'url': 'https://assets.msn.com/labs/mind/AAJQFgT.html', 'title_entities': '[{"Label": "Daphne Oz", "Type": "P", "WikidataId": "Q5221629", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Daphne Oz"]}]', 'abstract_entities': '[]', 'news_id': 1560}),
#  ConfigBox({'itemId': 'N50316', 'category': 'health', 'subcategory': 'nutrition', 'title': 'The Diet You Need for Healthy Lungs', 'abstract': 'How to build a plate that can fight off this serious respiratory disease', 'url': 'https://assets.msn.com/labs/mind/AAHMXC9.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 1717}),
#  ConfigBox({'itemId': 'N53615', 'category': 'health', 'subcategory': 'medical', 'title': "Here's What It Means If You Have Ridges on Your Nails", 'abstract': "They don't make for the prettiest of manicures, but are they something more than a cosmetic problem?", 'url': 'https://assets.msn.com/labs/mind/AAG7Lr3.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 1935}),
#  ConfigBox({'itemId': 'N45887', 'category': 'health', 'subcategory': 'medical', 'title': 'Why Are Uterine Cancer Rates Rising So Drastically in Black Women?', 'abstract': 'A CDC report found that black women are more likely to be diagnosed with the most aggressive form of uterine cancer.', 'url': 'https://assets.msn.com/labs/mind/AAJWM6y.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 1998}),
#  ConfigBox({'itemId': 'N56249', 'category': 'health', 'subcategory': 'wellness', 'title': '40 Health Myths Women Need to Stop Believing', 'abstract': 'Uh, I had no idea about some of these.', 'url': 'https://assets.msn.com/labs/mind/AAIoRgc.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 2202}),
#  ConfigBox({'itemId': 'N46597', 'category': 'health', 'subcategory': 'wellness', 'title': "The Before-And-After Photos of This Man Who's Three Years Sober Will Amaze You", 'abstract': "Alcohol was destroying Kenny Dunn's life. Now three years clean, his sobriety progression photos and the inspiring story behind them are going viral.", 'url': 'https://assets.msn.com/labs/mind/AAJWNfH.html', 'title_entities': '[{"Label": "Three Years", "Type": "U", "WikidataId": "Q3539951", "Confidence": 1.0, "OccurrenceOffsets": [46], "SurfaceForms": ["Three Years"]}, {"Label": "This Man (song)", "Type": "C", "WikidataId": "Q7786129", "Confidence": 0.929, "OccurrenceOffsets": [31], "SurfaceForms": ["This Man"]}]', 'abstract_entities': '[{"Label": "Three Years", "Type": "U", "WikidataId": "Q3539951", "Confidence": 1.0, "OccurrenceOffsets": [46], "SurfaceForms": ["three years"]}]', 'news_id': 2318}),
#  ConfigBox({'itemId': 'N21095', 'category': 'health', 'subcategory': 'medical', 'title': '6 Common Myths About the Flu Shot, Debunked', 'abstract': "There's a lot of misinformation floating around about the flu shot, which often dissuades a number of people from getting it.", 'url': 'https://assets.msn.com/labs/mind/AAJJkJz.html', 'title_entities': '[{"Label": "Influenza vaccine", "Type": "C", "WikidataId": "Q383260", "Confidence": 0.999, "OccurrenceOffsets": [25], "SurfaceForms": ["Flu Shot"]}]', 'abstract_entities': '[{"Label": "Influenza vaccine", "Type": "C", "WikidataId": "Q383260", "Confidence": 0.999, "OccurrenceOffsets": [58], "SurfaceForms": ["flu shot"]}]', 'news_id': 2480}),
#  ConfigBox({'itemId': 'N52782', 'category': 'health', 'subcategory': 'nutrition', 'title': '40 Best Belly-Shrinking Foods', 'abstract': "Yes, you can shrink your belly (and keep it flat!) if you just add these fat-frying foods to this week's grocery list.", 'url': 'https://assets.msn.com/labs/mind/AAB5Uv8.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 2493}),
#  ConfigBox({'itemId': 'N44399', 'category': 'health', 'subcategory': 'medical', 'title': 'Subtle Signs You May Have Clogged Arteries', 'abstract': 'These surprising clues can point to clogged arteries and underlying heart disease.', 'url': 'https://assets.msn.com/labs/mind/AAH1VSo.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 2567}),
#  ConfigBox({'itemId': 'N22061', 'category': 'health', 'subcategory': 'weightloss', 'title': '28 Simple Ways to Shrink Your Gut', 'abstract': 'Whittle your middle, improve your health, and gain confidence with these science-backed tips.', 'url': 'https://assets.msn.com/labs/mind/AAAOoQT.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 2665}),
#  ConfigBox({'itemId': 'N62853', 'category': 'health', 'subcategory': 'fitness', 'title': 'A bodybuilder showed how fitness influencers can make their bodies look Instagram-perfect in before-and-after photos', 'abstract': 'Connor Murphy posted a video to his YouTube channel in 2016 that highlights the ways people can manipulate their appearance for photos.', 'url': 'https://assets.msn.com/labs/mind/AAJJmnB.html', 'title_entities': '[{"Label": "Instagram", "Type": "W", "WikidataId": "Q209330", "Confidence": 1.0, "OccurrenceOffsets": [72], "SurfaceForms": ["Instagram"]}]', 'abstract_entities': '[{"Label": "YouTube", "Type": "O", "WikidataId": "Q866", "Confidence": 0.999, "OccurrenceOffsets": [36], "SurfaceForms": ["YouTube"]}]', 'news_id': 3102}),
#  ConfigBox({'itemId': 'N36933', 'category': 'health', 'subcategory': 'nutrition', 'title': '40 Foods Men Over 40 Should Avoid Like the Plague', 'abstract': 'Reading nutrition labels will help you make smarter food choices.', 'url': 'https://assets.msn.com/labs/mind/AAGRAxZ.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 3200}),
#  ConfigBox({'itemId': 'N28132', 'category': 'health', 'subcategory': 'nutrition', 'title': '13 Best Fall Superfoods for Weight Loss', 'abstract': "Stock up on these fall favorites that aren't only good for you, they'll also help you keep pounds off as the days turn colder.", 'url': 'https://assets.msn.com/labs/mind/AAGsojM.html', 'title_entities': '[{"Label": "Weight loss", "Type": "C", "WikidataId": "Q718113", "Confidence": 0.996, "OccurrenceOffsets": [28], "SurfaceForms": ["Weight Loss"]}]', 'abstract_entities': '[]', 'news_id': 3254}),
#  ConfigBox({'itemId': 'N22825', 'category': 'health', 'subcategory': 'wellness', 'title': 'How Long Does Alcohol Stay in Your System? We Asked an Expert', 'abstract': 'Did you know alcohol use can be detected months after your last drink?', 'url': 'https://assets.msn.com/labs/mind/AADbeE3.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 3357}),
#  ConfigBox({'itemId': 'N64296', 'category': 'health', 'subcategory': 'wellness', 'title': '22 Best Ways to Quit Smoking', 'abstract': 'Not sure how to quit smoking cigarettes? These tried-and-true tips have helped ex-smokers quit and go on to lead a smoke-free life.', 'url': 'https://assets.msn.com/labs/mind/AAIjaVT.html', 'title_entities': '[{"Label": "Smoking cessation", "Type": "C", "WikidataId": "Q2462253", "Confidence": 1.0, "OccurrenceOffsets": [8], "SurfaceForms": ["Ways to Quit Smoking"]}]', 'abstract_entities': '[]', 'news_id': 3932}),
#  ConfigBox({'itemId': 'N32074', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Can You Really Get Sick From Eating Raw Cookie Dough?', 'abstract': "You know you're not supposed to eat the stuff, but it's hard to resist raw cookie dough. Here's why it's so dangerous.", 'url': 'https://assets.msn.com/labs/mind/AAJWYYo.html', 'title_entities': '[{"Label": "Cookie dough", "Type": "C", "WikidataId": "Q5167099", "Confidence": 1.0, "OccurrenceOffsets": [40], "SurfaceForms": ["Cookie Dough"]}]', 'abstract_entities': '[{"Label": "Cookie dough", "Type": "C", "WikidataId": "Q5167099", "Confidence": 1.0, "OccurrenceOffsets": [75], "SurfaceForms": ["cookie dough"]}]', 'news_id': 4248}),
#  ConfigBox({'itemId': 'N4894', 'category': 'health', 'subcategory': 'voices', 'title': "I lost 20 pounds and felt amazing, but now I've regained the weight and am back where I started. What should I do?", 'abstract': 'The key is to start small and think about developing a healthier, more sustainable lifestyle rather than thinking about being on a diet.', 'url': 'https://assets.msn.com/labs/mind/AAJsJKp.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 4444}),
#  ConfigBox({'itemId': 'N33396', 'category': 'health', 'subcategory': 'weightloss', 'title': '14 Easy Ways to Jump-Start Your Metabolism', 'abstract': 'These simple tweaks to your daily routine will boost your weight loss in no time.', 'url': 'https://assets.msn.com/labs/mind/AAI9Rcn.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 4503}),
#  ConfigBox({'itemId': 'N8745', 'category': 'health', 'subcategory': 'wellness', 'title': 'The One Thing Kourtney Kardashian Drinks Every Morning for Younger-Looking Skin', 'abstract': 'Instead of waking up with a hot cup of coffee, the "Keeping Up with The Kardashians" star makes a warm collagen powder beverage to kick-start her day.', 'url': 'https://assets.msn.com/labs/mind/AAJAS6T.html', 'title_entities': '[{"Label": "Kourtney Kardashian", "Type": "P", "WikidataId": "Q575689", "Confidence": 1.0, "OccurrenceOffsets": [14], "SurfaceForms": ["Kourtney Kardashian"]}]', 'abstract_entities': '[{"Label": "Keeping Up with the Kardashians", "Type": "W", "WikidataId": "Q152108", "Confidence": 1.0, "OccurrenceOffsets": [52], "SurfaceForms": ["Keeping Up with The Kardashians"]}]', 'news_id': 4860}),
#  ConfigBox({'itemId': 'N11511', 'category': 'health', 'subcategory': 'wellness', 'title': '40 Health Habits Jennifer Lopez Swears By To Stay Insanely Fit And Young', 'abstract': '*Frantically takes notes*', 'url': 'https://assets.msn.com/labs/mind/AAIdpYV.html', 'title_entities': '[{"Label": "Jennifer Lopez", "Type": "P", "WikidataId": "Q40715", "Confidence": 1.0, "OccurrenceOffsets": [17], "SurfaceForms": ["Jennifer Lopez"]}, {"Label": "Insanity", "Type": "C", "WikidataId": "Q505619", "Confidence": 1.0, "OccurrenceOffsets": [50], "SurfaceForms": ["Insanely"]}]', 'abstract_entities': '[]', 'news_id': 5256}),
#  ConfigBox({'itemId': 'N49489', 'category': 'health', 'subcategory': 'wellness', 'title': 'Simple Tricks To Deal With Stress', 'abstract': "We asked country's top doctors how you can quickly and easily reduce your stress. Based on what they told us we prepared these simple tips.", 'url': 'https://assets.msn.com/labs/mind/AAJATti.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 5504}),
#  ConfigBox({'itemId': 'N47235', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Nutritionists share their favorite packaged foods for quick meals', 'abstract': 'Dinner is about to get a whole lot easier.', 'url': 'https://assets.msn.com/labs/mind/AAIeovf.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 5836}),
#  ConfigBox({'itemId': 'N17482', 'category': 'health', 'subcategory': 'wellness', 'title': 'Chin Hair: 7 Embarrassing Red Flags No Woman Should Ever Ignore', 'abstract': "Here's how to know if your annoying chin hair is a sign of a more serious issue.", 'url': 'https://assets.msn.com/labs/mind/AAE8L04.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 6136}),
#  ConfigBox({'itemId': 'N31448', 'category': 'health', 'subcategory': 'wellness', 'title': "Four words from dermatologists that'll change your life: Stop showering every day", 'abstract': 'Whoa. "It doesn\'t matter what time of year it is   your entire body does not need to be washed daily," says one derm (and she has backup).', 'url': 'https://assets.msn.com/labs/mind/AAIx2VT.html', 'title_entities': '[{"Label": "Dermatology", "Type": "C", "WikidataId": "Q171171", "Confidence": 1.0, "OccurrenceOffsets": [16], "SurfaceForms": ["dermatologists"]}]', 'abstract_entities': '[]', 'news_id': 6192}),
#  ConfigBox({'itemId': 'N56301', 'category': 'health', 'subcategory': 'fitness', 'title': '10 Ways to Burn Belly Fat in 10 Minutes', 'abstract': 'The good news: Getting your abs back is possible. The bad news: Losing your belly fat is time-consuming and requires dedication to a good diet and regular exercise.', 'url': 'https://assets.msn.com/labs/mind/AAD4pFw.html', 'title_entities': '[{"Label": "Adipose tissue", "Type": "C", "WikidataId": "Q193583", "Confidence": 1.0, "OccurrenceOffsets": [16], "SurfaceForms": ["Belly Fat"]}]', 'abstract_entities': '[{"Label": "Adipose tissue", "Type": "C", "WikidataId": "Q193583", "Confidence": 1.0, "OccurrenceOffsets": [76], "SurfaceForms": ["belly fat"]}]', 'news_id': 6441}),
#  ConfigBox({'itemId': 'N11032', 'category': 'health', 'subcategory': 'medical', 'title': 'Hormone Therapy for Breast Cancer', 'abstract': 'Treatments that suppress hormones in the body have been found helpful for some kinds of breast cancer.', 'url': 'https://assets.msn.com/labs/mind/AAJQPJY.html', 'title_entities': '[{"Label": "Breast cancer", "Type": "C", "WikidataId": "Q128581", "Confidence": 1.0, "OccurrenceOffsets": [20], "SurfaceForms": ["Breast Cancer"]}]', 'abstract_entities': '[{"Label": "Breast cancer", "Type": "C", "WikidataId": "Q128581", "Confidence": 1.0, "OccurrenceOffsets": [88], "SurfaceForms": ["breast cancer"]}]', 'news_id': 6523}),
#  ConfigBox({'itemId': 'N1080', 'category': 'health', 'subcategory': 'health-news', 'title': "Do This One Thing Every Day and You'll Increase Your Risk of Stroke by 29 Percent", 'abstract': 'A new study published in the journal Stroke has found that people under age 50 had a higher risk of stroke when working for more than 10 hours a day.', 'url': 'https://assets.msn.com/labs/mind/AADecOq.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Stroke (journal)", "Type": "M", "WikidataId": "Q7624282", "Confidence": 0.999, "OccurrenceOffsets": [37], "SurfaceForms": ["Stroke"]}]', 'news_id': 6587}),
#  ConfigBox({'itemId': 'N12627', 'category': 'health', 'subcategory': 'fitness', 'title': '6 Reasons to Run On the Treadmill Instead of Outside', 'abstract': 'Two words: heat and humidity.', 'url': 'https://assets.msn.com/labs/mind/AAFxaUW.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 6590}),
#  ConfigBox({'itemId': 'N13575', 'category': 'health', 'subcategory': 'wellness', 'title': 'What happens in your body when you sneeze?', 'abstract': 'Here are some wacky things that happen to your body with every "achoo!"', 'url': 'https://assets.msn.com/labs/mind/AAH8M4N.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 6717}),
#  ConfigBox({'itemId': 'N8260', 'category': 'health', 'subcategory': 'weightloss', 'title': "Kristina Went From 'Drastic Diets' to Losing 105 Pounds With WW - Here's How She Did It", 'abstract': 'Kristina had tried "drastic diets" and would stick to them for a while, but eventually she\'d resort to "old habits and the weight would be put back on," she says.', 'url': 'https://assets.msn.com/labs/mind/AAG0Sjs.html', 'title_entities': '[{"Label": "WW International", "Type": "N", "WikidataId": "Q1929466", "Confidence": 1.0, "OccurrenceOffsets": [61], "SurfaceForms": ["WW"]}]', 'abstract_entities': '[]', 'news_id': 6742}),
#  ConfigBox({'itemId': 'N44030', 'category': 'health', 'subcategory': 'wellness', 'title': 'Ballet star, 100, shares optimism and other secrets to long life', 'abstract': "You have to take care of yourself. This body is the only thing you've got, Henry Danton says.", 'url': 'https://assets.msn.com/labs/mind/AAH9czV.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 6990}),
#  ConfigBox({'itemId': 'N30215', 'category': 'health', 'subcategory': 'weightloss', 'title': 'This Man Ate the Same Thing for Four Years and Dropped 145 Pounds', 'abstract': 'My lunchbox saved my life, says Ian Sullivan.', 'url': 'https://assets.msn.com/labs/mind/AAHAA2g.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 7183}),
#  ConfigBox({'itemId': 'N23864', 'category': 'health', 'subcategory': 'nutrition', 'title': "Here's Exactly What Kristen Bell Eats in a Day to Make 39 Look Like 29", 'abstract': 'Find out how the actress, entrepreneur, activist and mom of two ages with grace.', 'url': 'https://assets.msn.com/labs/mind/AAJm1H7.html', 'title_entities': '[{"Label": "Kristen Bell", "Type": "P", "WikidataId": "Q178882", "Confidence": 1.0, "OccurrenceOffsets": [20], "SurfaceForms": ["Kristen Bell"]}]', 'abstract_entities': '[]', 'news_id': 7374}),
#  ConfigBox({'itemId': 'N26066', 'category': 'health', 'subcategory': 'fitness', 'title': 'How Skipping Breakfast Can Hurt You at the Gym', 'abstract': 'Want to get stronger? Training fasted might not be the way to go.', 'url': 'https://assets.msn.com/labs/mind/AAJX1xM.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 7432}),
#  ConfigBox({'itemId': 'N40268', 'category': 'health', 'subcategory': 'weightloss', 'title': 'Andy Cohen Says He Lost 12 Pounds in 3 Months By Simply Cutting Out Booze', 'abstract': 'Andy Cohen revealed that he lost 12 pounds in three months while co-hosting "Today" with Hoda Kotb. "This summer, I had a moment where I was like, I really felt like my suits were getting tight," he said.', 'url': 'https://assets.msn.com/labs/mind/AAJX26S.html', 'title_entities': '[{"Label": "Andy Cohen (TV personality)", "Type": "N", "WikidataId": "Q2014922", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Andy Cohen"]}, {"Label": "Naval boarding", "Type": "C", "WikidataId": "Q648919", "Confidence": 1.0, "OccurrenceOffsets": [56], "SurfaceForms": ["Cutting Out"]}]', 'abstract_entities': '[{"Label": "Andy Cohen (TV personality)", "Type": "N", "WikidataId": "Q2014922", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Andy Cohen"]}, {"Label": "Hoda Kotb", "Type": "P", "WikidataId": "Q5875916", "Confidence": 1.0, "OccurrenceOffsets": [89], "SurfaceForms": ["Hoda Kotb"]}, {"Label": "Today (American TV program)", "Type": "N", "WikidataId": "Q130838", "Confidence": 0.999, "OccurrenceOffsets": [77], "SurfaceForms": ["Today"]}]', 'news_id': 7475}),
#  ConfigBox({'itemId': 'N60895', 'category': 'health', 'subcategory': 'voices', 'title': 'Why I Stayed in An Abusive Relationship', 'abstract': 'Leaving an abusive relationship is harder than you think.', 'url': 'https://assets.msn.com/labs/mind/AAJsX0v.html', 'title_entities': '[{"Label": "Relational aggression", "Type": "C", "WikidataId": "Q8191685", "Confidence": 0.958, "OccurrenceOffsets": [19], "SurfaceForms": ["Abusive Relationship"]}]', 'abstract_entities': '[{"Label": "Relational aggression", "Type": "C", "WikidataId": "Q8191685", "Confidence": 0.958, "OccurrenceOffsets": [11], "SurfaceForms": ["abusive relationship"]}]', 'news_id': 7883}),
#  ConfigBox({'itemId': 'N63650', 'category': 'health', 'subcategory': 'medical', 'title': 'What Causes Vertigo? 15 Things Doctors Wish You Knew', 'abstract': 'The spinning, dizzying loss of balance that indicates vertigo can come without warning.', 'url': 'https://assets.msn.com/labs/mind/AAIAj5W.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 8672}),
#  ConfigBox({'itemId': 'N59272', 'category': 'health', 'subcategory': 'nutrition', 'title': '40 Restaurant Meals You Should Never Eat After 40', 'abstract': "As you age, you're at a higer risk for heart disease, diabetes, and muscle loss. Here's a list of 40 restaurant dishes to avoid after 40.", 'url': 'https://assets.msn.com/labs/mind/AAJF5FW.html', 'title_entities': '[{"Label": "East Africa Time", "Type": "U", "WikidataId": "Q1773949", "Confidence": 0.918, "OccurrenceOffsets": [37], "SurfaceForms": ["Eat"]}]', 'abstract_entities': '[]', 'news_id': 8866}),
#  ConfigBox({'itemId': 'N33203', 'category': 'health', 'subcategory': 'weightloss', 'title': 'Gradual lifestyle changes helped this woman lose 75 pounds and keep it off', 'abstract': 'Jess Dukes says her weight loss journey began with a tiny change: swapping sugar and cream in her coffee with Stevia and almond milk.', 'url': 'https://assets.msn.com/labs/mind/AAJX9Uc.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 9036}),
#  ConfigBox({'itemId': 'N46724', 'category': 'health', 'subcategory': 'wellness', 'title': 'Waking up in the middle of the night? Your big dinner could be to blame', 'abstract': "A good rule of thumb for the best time to eat dinner is at least two to three hours before getting into bed. And don't eat a lot.", 'url': 'https://assets.msn.com/labs/mind/AAJR0hS.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 9088}),
#  ConfigBox({'itemId': 'N16380', 'category': 'health', 'subcategory': 'wellness', 'title': 'Whitney Way Thore Responds After Trolls Shamed Her for Attempting a Power Snatch', 'abstract': 'My Big Fat Fabulous Life star Whitney Way Thore attempted an Olympic weightlifting move known as a power snatch. The trolls came out, but Whitney let her progress speak for itself.', 'url': 'https://assets.msn.com/labs/mind/AAJF6NQ.html', 'title_entities': '[{"Label": "Whitney Way Thore", "Type": "P", "WikidataId": "Q19667192", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Whitney Way Thore"]}, {"Label": "Snatch (weightlifting)", "Type": "C", "WikidataId": "Q14786282", "Confidence": 1.0, "OccurrenceOffsets": [68], "SurfaceForms": ["Power Snatch"]}]', 'abstract_entities': '[{"Label": "Whitney Way Thore", "Type": "P", "WikidataId": "Q19667192", "Confidence": 1.0, "OccurrenceOffsets": [32, 140], "SurfaceForms": ["Whitney Way Thore", "Whitney"]}, {"Label": "Snatch (weightlifting)", "Type": "C", "WikidataId": "Q14786282", "Confidence": 1.0, "OccurrenceOffsets": [101], "SurfaceForms": ["power snatch"]}, {"Label": "My Big Fat Fabulous Life", "Type": "W", "WikidataId": "Q18786453", "Confidence": 1.0, "OccurrenceOffsets": [1], "SurfaceForms": ["My Big Fat Fabulous Life"]}]', 'news_id': 9183}),
#  ConfigBox({'itemId': 'N4247', 'category': 'health', 'subcategory': 'nutrition', 'title': 'The keto diet is hard work   but this hack makes it so much easier', 'abstract': "Let's face it: Healthy, keto-friendly meals require some form of food prep.", 'url': 'https://assets.msn.com/labs/mind/AAJLKHE.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 9933}),
#  ConfigBox({'itemId': 'N41569', 'category': 'health', 'subcategory': 'nutrition', 'title': "I tried to eat like Kate Middleton for a week, but I couldn't get through it without cheating", 'abstract': "Following Kate Middleton's diet helped me feel energized throughout the week, but there were some meals I could only stomach once.", 'url': 'https://assets.msn.com/labs/mind/AAJLltk.html', 'title_entities': '[{"Label": "Catherine, Duchess of Cambridge", "Type": "P", "WikidataId": "Q10479", "Confidence": 1.0, "OccurrenceOffsets": [20], "SurfaceForms": ["Kate Middleton"]}]', 'abstract_entities': '[{"Label": "Catherine, Duchess of Cambridge", "Type": "P", "WikidataId": "Q10479", "Confidence": 1.0, "OccurrenceOffsets": [10], "SurfaceForms": ["Kate Middleton"]}, {"Label": "Following", "Type": "W", "WikidataId": "Q685817", "Confidence": 0.938, "OccurrenceOffsets": [0], "SurfaceForms": ["Following"]}]', 'news_id': 11493}),
#  ConfigBox({'itemId': 'N44278', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Real talk: How freaked should I be about the sugar content in alcohol?', 'abstract': "It's (mostly) good news, promise.", 'url': 'https://assets.msn.com/labs/mind/AAJRzgX.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 11704}),
#  ConfigBox({'itemId': 'N63656', 'category': 'health', 'subcategory': 'wellness', 'title': "Model Belle Lucia   Who Was Shamed for Her Small Bump   Shares Her Post-Baby 'Pregnancy Transformation'", 'abstract': 'Belle Lucia was shamed by Instagram commenters who thought her baby bump was too small, but she says she gained 44 pounds. "More than average," she said.', 'url': 'https://assets.msn.com/labs/mind/AAJtAgo.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Instagram", "Type": "W", "WikidataId": "Q209330", "Confidence": 1.0, "OccurrenceOffsets": [26], "SurfaceForms": ["Instagram"]}]', 'news_id': 11809}),
#  ConfigBox({'itemId': 'N39978', 'category': 'health', 'subcategory': 'nutrition', 'title': '30 Foods That Are Never Worth The Calories', 'abstract': 'What a waste of stomach space!', 'url': 'https://assets.msn.com/labs/mind/AAJXMR9.html', 'title_entities': '[{"Label": "Calorie", "Type": "C", "WikidataId": "Q130964", "Confidence": 1.0, "OccurrenceOffsets": [30], "SurfaceForms": ["The Calories"]}]', 'abstract_entities': '[]', 'news_id': 12497}),
#  ConfigBox({'itemId': 'N52447', 'category': 'health', 'subcategory': 'wellness', 'title': 'Should You Drink Water Before Bed?', 'abstract': 'Check out the benefits as well as one big drawback before sneaking downstairs for your midnight thirst quencher.', 'url': 'https://assets.msn.com/labs/mind/AAJBNUH.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 12557}),
#  ConfigBox({'itemId': 'N724', 'category': 'health', 'subcategory': 'health-news', 'title': "Most Food in America is Hyper-Palatable and 'Difficult to Stop Eating,' Scientists Say", 'abstract': "'Don't eat anything your great grandmother wouldn't recognize as food' an author of the study told Newsweek.", 'url': 'https://assets.msn.com/labs/mind/AAJSLCR.html', 'title_entities': '[{"Label": "United States", "Type": "G", "WikidataId": "Q30", "Confidence": 0.973, "OccurrenceOffsets": [13], "SurfaceForms": ["America"]}]', 'abstract_entities': '[{"Label": "Newsweek", "Type": "M", "WikidataId": "Q188413", "Confidence": 1.0, "OccurrenceOffsets": [99], "SurfaceForms": ["Newsweek"]}]', 'news_id': 12632}),
#  ConfigBox({'itemId': 'N16323', 'category': 'health', 'subcategory': 'video', 'title': "Is It Actually Harder to Lose Weight When You're Short?", 'abstract': "What you need to know about weight loss if you're vertically challenged.", 'url': 'https://assets.msn.com/labs/mind/AAJXMyG.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 12652}),
#  ConfigBox({'itemId': 'N10560', 'category': 'health', 'subcategory': 'medical', 'title': 'What Are Ocular Migraines and How Are They Different from Regular Migraines?', 'abstract': 'For starters, ocular migraines are pretty rare.', 'url': 'https://assets.msn.com/labs/mind/AAJSUBY.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 13150}),
#  ConfigBox({'itemId': 'N3128', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Should You Try the Controversial Cabbage Soup Diet? See What Experts Have to Say', 'abstract': 'Have you tried the cabbage soup diet, the 7-day program where soup is most of your food? We asked the experts to chime in on its effectiveness and safety.', 'url': 'https://assets.msn.com/labs/mind/AAJXR6V.html', 'title_entities': '[{"Label": "Cabbage soup diet", "Type": "C", "WikidataId": "Q1778730", "Confidence": 1.0, "OccurrenceOffsets": [33], "SurfaceForms": ["Cabbage Soup Diet"]}]', 'abstract_entities': '[{"Label": "Cabbage soup diet", "Type": "C", "WikidataId": "Q1778730", "Confidence": 1.0, "OccurrenceOffsets": [19], "SurfaceForms": ["cabbage soup diet"]}]', 'news_id': 13506}),
#  ConfigBox({'itemId': 'N51223', 'category': 'health', 'subcategory': 'medical', 'title': 'How to Decide If the Amniocentesis Test Is Worth It', 'abstract': 'The test is invasive, risky, and potentially very important.', 'url': 'https://assets.msn.com/labs/mind/AAIZM9N.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 14004}),
#  ConfigBox({'itemId': 'N11484', 'category': 'health', 'subcategory': 'voices', 'title': "'At 237 Lbs., I Was Embarrassed To Go To The Gym. So I Did An At-Home BeachBody Program And Lost 117 Lbs.'", 'abstract': 'I wanted to be me again.', 'url': 'https://assets.msn.com/labs/mind/AAJT6sG.html', 'title_entities': '[{"Label": "Take-out", "Type": "U", "WikidataId": "Q154383", "Confidence": 1.0, "OccurrenceOffsets": [32], "SurfaceForms": ["To Go"]}, {"Label": "None of the above", "Type": "U", "WikidataId": "Q2345115", "Confidence": 1.0, "OccurrenceOffsets": [88], "SurfaceForms": ["And Lost"]}, {"Label": "Gym", "Type": "C", "WikidataId": "Q14092", "Confidence": 0.94, "OccurrenceOffsets": [41], "SurfaceForms": ["The Gym"]}]', 'abstract_entities': '[]', 'news_id': 15304}),
#  ConfigBox({'itemId': 'N4741', 'category': 'health', 'subcategory': 'nutrition', 'title': 'What Is Clean Fasting, and How Will It Help You Speed Up Weight Loss?', 'abstract': "No matter what intermittent fasting schedule you're on, if you found that you're not losing weight or you've hit a weight-loss plateau, it could be because you're not clean fasting.", 'url': 'https://assets.msn.com/labs/mind/AAJXc6K.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 15572}),
#  ConfigBox({'itemId': 'N45609', 'category': 'health', 'subcategory': 'medical', 'title': 'Silent Signs of Colon Cancer', 'abstract': 'Colon cancer remains the second most lethal cancer in men and third most in women. Here are the signs and symptoms of colon cancer you need to look out for.', 'url': 'https://assets.msn.com/labs/mind/AAJFwzW.html', 'title_entities': '[{"Label": "Colorectal cancer", "Type": "C", "WikidataId": "Q188874", "Confidence": 1.0, "OccurrenceOffsets": [16], "SurfaceForms": ["Colon Cancer"]}]', 'abstract_entities': '[{"Label": "Colorectal cancer", "Type": "C", "WikidataId": "Q188874", "Confidence": 1.0, "OccurrenceOffsets": [0, 118], "SurfaceForms": ["Colon cancer", "colon cancer"]}]', 'news_id': 15699}),
#  ConfigBox({'itemId': 'N9475', 'category': 'health', 'subcategory': 'nutrition', 'title': "Subtle Signs You're Eating Too Much Sugar", 'abstract': "Are you eating too much sugar? And how much is too much? These are the symptoms that often go unnoticed when you're eating more sugar than you should.", 'url': 'https://assets.msn.com/labs/mind/AAJuKLp.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 17646}),
#  ConfigBox({'itemId': 'N17701', 'category': 'health', 'subcategory': 'weightloss', 'title': "The 'weight loss' teas you've seen on Instagram are a scam, but there are teas with appetite-curbing benefits", 'abstract': 'Some of the teas aren\'t "diet" at all, they\'re just emptying out your insides. Here\'s what to know about teas that are safe and healthy.', 'url': 'https://assets.msn.com/labs/mind/AAJXnet.html', 'title_entities': '[{"Label": "Instagram", "Type": "W", "WikidataId": "Q209330", "Confidence": 1.0, "OccurrenceOffsets": [38], "SurfaceForms": ["Instagram"]}]', 'abstract_entities': '[]', 'news_id': 18070}),
#  ConfigBox({'itemId': 'N27993', 'category': 'health', 'subcategory': 'wellness', 'title': 'Exactly What to Do When Your Belly Button Smells Funky', 'abstract': 'That sneaky little spot harbors 60 kinds of bacteria!', 'url': 'https://assets.msn.com/labs/mind/AAJXr01.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 18827}),
#  ConfigBox({'itemId': 'N10944', 'category': 'health', 'subcategory': 'causes', 'title': "What Causes Alzheimer's?", 'abstract': "Alzheimer's can start mild and ultimately leave a person unable to carry out daily activities. That's why discovering the cause is so important.", 'url': 'https://assets.msn.com/labs/mind/AAJysKL.html', 'title_entities': '[{"Label": "Alzheimer\'s disease", "Type": "U", "WikidataId": "Q11081", "Confidence": 0.988, "OccurrenceOffsets": [12], "SurfaceForms": ["Alzheimer\'s"]}]', 'abstract_entities': '[{"Label": "Alzheimer\'s disease", "Type": "U", "WikidataId": "Q11081", "Confidence": 0.988, "OccurrenceOffsets": [0], "SurfaceForms": ["Alzheimer\'s"]}]', 'news_id': 19415}),
#  ConfigBox({'itemId': 'N9763', 'category': 'health', 'subcategory': 'nutrition', 'title': "Here's What Kate Hudson Eats in a Day to Stay Sculpted at 40", 'abstract': 'The actress, co-founder of Fabletics and mommy of three seeks balance in order to stay fit.', 'url': 'https://assets.msn.com/labs/mind/AAJTRXD.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Fabletics", "Type": "O", "WikidataId": "Q16992933", "Confidence": 1.0, "OccurrenceOffsets": [27], "SurfaceForms": ["Fabletics"]}]', 'news_id': 19570}),
#  ConfigBox({'itemId': 'N23485', 'category': 'health', 'subcategory': 'ads-lung-health', 'title': '5 Things No One Tells You About Living With Lung Cancer', 'abstract': 'For starters, so many people will ask if you smoked.', 'url': 'https://assets.msn.com/labs/mind/AAJGoFA.html', 'title_entities': '[{"Label": "Lung cancer", "Type": "C", "WikidataId": "Q47912", "Confidence": 1.0, "OccurrenceOffsets": [44], "SurfaceForms": ["Lung Cancer"]}]', 'abstract_entities': '[]', 'news_id': 19992}),
#  ConfigBox({'itemId': 'N45456', 'category': 'health', 'subcategory': 'wellness', 'title': 'Why you should give up alcohol for one month: From improved sleep to a glowing complexion - this is EXACTLY what happens to your body when you ditch booze for just four weeks', 'abstract': 'Penny Adams, an Australian doctor, reveals how quickly your health (and your looks) can improve after quitting drinking for just 30 days.', 'url': 'https://assets.msn.com/labs/mind/AAJjGSV.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 21374}),
#  ConfigBox({'itemId': 'N52761', 'category': 'health', 'subcategory': 'health-news', 'title': "Kim Kardashian West says she's gained 18 pounds in the past year", 'abstract': 'The reality TV star is determined to whip herself back into shape.', 'url': 'https://assets.msn.com/labs/mind/AAJOKpj.html', 'title_entities': '[{"Label": "Kim Kardashian", "Type": "P", "WikidataId": "Q186304", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Kim Kardashian West"]}]', 'abstract_entities': '[]', 'news_id': 22163}),
#  ConfigBox({'itemId': 'N58885', 'category': 'health', 'subcategory': 'fitness', 'title': '3 Months of Full Body Workouts Helped This Guy Get Shredded at 40', 'abstract': 'Mat Smith ramped up his workouts and found an online support group to share fitness goals.', 'url': 'https://assets.msn.com/labs/mind/AAJTmJd.html', 'title_entities': '[{"Label": "Full body scanner", "Type": "C", "WikidataId": "Q154055", "Confidence": 1.0, "OccurrenceOffsets": [12], "SurfaceForms": ["Full Body"]}]', 'abstract_entities': '[]', 'news_id': 22548}),
#  ConfigBox({'itemId': 'N64515', 'category': 'health', 'subcategory': 'weightloss', 'title': "Jillian Michaels Says Intermittent Fasting 'Isn't Actually Good For Weight Loss'", 'abstract': "That's just not true.", 'url': 'https://assets.msn.com/labs/mind/AAJTtO9.html', 'title_entities': '[{"Label": "Intermittent fasting", "Type": "U", "WikidataId": "Q1666254", "Confidence": 1.0, "OccurrenceOffsets": [22], "SurfaceForms": ["Intermittent Fasting"]}, {"Label": "Jillian Michaels", "Type": "P", "WikidataId": "Q2971799", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Jillian Michaels"]}]', 'abstract_entities': '[]', 'news_id': 23603}),
#  ConfigBox({'itemId': 'N40475', 'category': 'health', 'subcategory': 'nutrition', 'title': "Nutrients That Surprisingly You Can't Obtain From Plants", 'abstract': "There are several nutrients that only an animal-sourced food can supplement, which the vegetarian diet can't.", 'url': 'https://assets.msn.com/labs/mind/AAJOhT0.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 23944}),
#  ConfigBox({'itemId': 'N32011', 'category': 'health', 'subcategory': 'causes', 'title': '27 Things No One Tells You About Having Diabetes', 'abstract': "Discover the realities of living with diabetes that nobody tells you until you're diagnosed and actually experiencing them.", 'url': 'https://assets.msn.com/labs/mind/AAJOxJ5.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 25072}),
#  ConfigBox({'itemId': 'N41073', 'category': 'health', 'subcategory': 'nutrition', 'title': 'The Secret to Sticking with Keto', 'abstract': 'Is it possible to take a cheat day while on the keto diet? We asked the experts if this was possible, and if you would fall out of ketosis from one meal.', 'url': 'https://assets.msn.com/labs/mind/AAJe9jS.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 27300}),
#  ConfigBox({'itemId': 'N61274', 'category': 'health', 'subcategory': 'ads-lung-health', 'title': 'Eating Enough of These Two Nutrients May Help Lower Your Risk of Lung Cancer', 'abstract': "They're already found in some of your favorite foods.", 'url': 'https://assets.msn.com/labs/mind/AAJPnsw.html', 'title_entities': '[{"Label": "Eating", "Type": "C", "WikidataId": "Q213449", "Confidence": 0.931, "OccurrenceOffsets": [0], "SurfaceForms": ["Eating"]}]', 'abstract_entities': '[]', 'news_id': 27448}),
#  ConfigBox({'itemId': 'N59576', 'category': 'health', 'subcategory': 'wellness', 'title': 'Venting can be super healthy until 1 common pitfall gets in the way', 'abstract': "As much as we get a feel-good release when we're complaining about our boss, we need to put a time limit on our venting sessions. Here's why.", 'url': 'https://assets.msn.com/labs/mind/AAJPw1G.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 27564}),
#  ConfigBox({'itemId': 'N4550', 'category': 'health', 'subcategory': 'wellness', 'title': "Demi Moore Said Her Marriage to Ashton Kutcher Was a 'Codependency.' Here's What That Means", 'abstract': 'So what does it mean to be "addicted" to a person and describe a relationship as a codependency? Health experts explain.', 'url': 'https://assets.msn.com/labs/mind/AAJUix2.html', 'title_entities': '[{"Label": "Demi Moore", "Type": "P", "WikidataId": "Q43044", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Demi Moore"]}, {"Label": "Ashton Kutcher", "Type": "P", "WikidataId": "Q164782", "Confidence": 1.0, "OccurrenceOffsets": [32], "SurfaceForms": ["Ashton Kutcher"]}]', 'abstract_entities': '[]', 'news_id': 28025}),
#  ConfigBox({'itemId': 'N49364', 'category': 'health', 'subcategory': 'medical', 'title': 'Dangers of tattoos are more than just skin deep', 'abstract': 'Skin experts say people should consider sanitation and potential allergic reactions before getting a tattoo.', 'url': 'https://assets.msn.com/labs/mind/AAJvxAj.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 28258}),
#  ConfigBox({'itemId': 'N48476', 'category': 'health', 'subcategory': 'voices', 'title': 'I Have Smiling Depression This Is What It Feels Like', 'abstract': "I function but do not feel. My face says I'm happy, but inside I want to cry.", 'url': 'https://assets.msn.com/labs/mind/AAJIgOB.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 28347}),
#  ConfigBox({'itemId': 'N51773', 'category': 'health', 'subcategory': 'voices', 'title': "'I Stayed Off Social Media Entirely Because Of My Weight. Then I Discovered Intermittent Fasting And Lost 109 Lbs.'", 'abstract': 'After going through years of cancer treatment, Alicia Latrice Smith says she gained a lot of weight. She tweaked her diet   and lost 109 pounds.', 'url': 'https://assets.msn.com/labs/mind/AAJw3lX.html', 'title_entities': '[{"Label": "None of the above", "Type": "U", "WikidataId": "Q2345115", "Confidence": 1.0, "OccurrenceOffsets": [97], "SurfaceForms": ["And Lost"]}, {"Label": "Intermittent fasting", "Type": "U", "WikidataId": "Q1666254", "Confidence": 1.0, "OccurrenceOffsets": [76], "SurfaceForms": ["Intermittent Fasting"]}, {"Label": "Social media", "Type": "C", "WikidataId": "Q202833", "Confidence": 0.998, "OccurrenceOffsets": [14], "SurfaceForms": ["Social Media"]}]', 'abstract_entities': '[{"Label": "None of the above", "Type": "U", "WikidataId": "Q2345115", "Confidence": 1.0, "OccurrenceOffsets": [124], "SurfaceForms": ["and lost"]}]', 'news_id': 28572}),
#  ConfigBox({'itemId': 'N21147', 'category': 'health', 'subcategory': 'weightloss', 'title': '33 Surprising Reasons To Lose Weight', 'abstract': 'The case to get healthy is rooted in a better life not better looks.', 'url': 'https://assets.msn.com/labs/mind/AAJUpHt.html', 'title_entities': '[{"Label": "Weight loss", "Type": "C", "WikidataId": "Q718113", "Confidence": 1.0, "OccurrenceOffsets": [25], "SurfaceForms": ["Lose Weight"]}, {"Label": "Smle (DJs)", "Type": "N", "WikidataId": "Q58022599", "Confidence": 1.0, "OccurrenceOffsets": [14], "SurfaceForms": ["Reasons To"]}]', 'abstract_entities': '[]', 'news_id': 29167}),
#  ConfigBox({'itemId': 'N47040', 'category': 'health', 'subcategory': 'weightloss', 'title': '15 Food Myths That Are Causing You to Gain Weight', 'abstract': "When it comes to watching your weight, if you naturally trust in every tip or trick you hear whether it's from a nutritionist, your best friend, or a product label, you're setting yourself up for some serious scale issues.", 'url': 'https://assets.msn.com/labs/mind/AAJUqyt.html', 'title_entities': '[{"Label": "Weight gain", "Type": "C", "WikidataId": "Q3403879", "Confidence": 1.0, "OccurrenceOffsets": [38], "SurfaceForms": ["Gain Weight"]}]', 'abstract_entities': '[]', 'news_id': 29472}),
#  ConfigBox({'itemId': 'N56105', 'category': 'health', 'subcategory': 'weightloss', 'title': 'Losing Weight Overnight: How Your Sleep Pattern Helps Promote Weight Loss', 'abstract': 'Sleep has been found helping maintain or reduce weight but is it possible to shed some pounds overnight?', 'url': 'https://assets.msn.com/labs/mind/AAJVbu1.html', 'title_entities': '[{"Label": "Weight loss", "Type": "C", "WikidataId": "Q718113", "Confidence": 0.916, "OccurrenceOffsets": [62], "SurfaceForms": ["Weight Loss"]}, {"Label": "Sleep", "Type": "C", "WikidataId": "Q35831", "Confidence": 1.0, "OccurrenceOffsets": [34], "SurfaceForms": ["Sleep Pattern"]}]', 'abstract_entities': '[]', 'news_id': 30628}),
# ...
#  ConfigBox({'itemId': 'N5827', 'category': 'health', 'subcategory': 'medical', 'title': "You can't get the flu from the flu shot, but there are side effects", 'abstract': 'Contrary to popular belief, the flu shot cannot give you the flu. However, you may experience some side effects after getting vaccinated.', 'url': 'https://assets.msn.com/labs/mind/BBWqwoF.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48164}),
#  ConfigBox({'itemId': 'N15784', 'category': 'health', 'subcategory': 'healthnews', 'title': 'WHO prequalifies first Ebola vaccine', 'abstract': 'The World Health Organization (WHO) on Tuesday said it had prequalified an Ebola vaccine for the first time, hailing a "critical step" towards its licensing, access and roll-out in countries most at risk of outbreaks.', 'url': 'https://assets.msn.com/labs/mind/BBWG0ql.html', 'title_entities': '[{"Label": "Ebola virus disease", "Type": "U", "WikidataId": "Q51993", "Confidence": 1.0, "OccurrenceOffsets": [23], "SurfaceForms": ["Ebola"]}]', 'abstract_entities': '[{"Label": "Ebola virus disease", "Type": "U", "WikidataId": "Q51993", "Confidence": 1.0, "OccurrenceOffsets": [75], "SurfaceForms": ["Ebola"]}, {"Label": "World Health Organization", "Type": "O", "WikidataId": "Q7817", "Confidence": 1.0, "OccurrenceOffsets": [4], "SurfaceForms": ["World Health Organization"]}]', 'news_id': 48165}),
#  ConfigBox({'itemId': 'N48445', 'category': 'health', 'subcategory': 'health-news', 'title': 'New Study Reveals You Burn More Than 50,000 Calories a Month Parenting', 'abstract': "Feeling bad that you couldn't make your spin class again? Don't! A new study says parenting tasks burn 50,000 calories per month.", 'url': 'https://assets.msn.com/labs/mind/BBWqwvM.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48196}),
#  ConfigBox({'itemId': 'N6566', 'category': 'health', 'subcategory': 'nutrition', 'title': 'Health Benefits of Nutritional Yeast and How to Use It', 'abstract': 'Vegans love the cheesy, umami flavor and there are some serious health reasons to choose nutritional yeast.', 'url': 'https://assets.msn.com/labs/mind/BBWImqO.html', 'title_entities': '[{"Label": "Nutritional yeast", "Type": "C", "WikidataId": "Q1786540", "Confidence": 1.0, "OccurrenceOffsets": [19], "SurfaceForms": ["Nutritional Yeast"]}]', 'abstract_entities': '[{"Label": "Nutritional yeast", "Type": "C", "WikidataId": "Q1786540", "Confidence": 1.0, "OccurrenceOffsets": [89], "SurfaceForms": ["nutritional yeast"]}, {"Label": "Veganism", "Type": "C", "WikidataId": "Q181138", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Vegans"]}]', 'news_id': 48291}),
#  ConfigBox({'itemId': 'N37905', 'category': 'health', 'subcategory': 'wellness', 'title': 'You Need To Prioritize Sleep, According To Science', 'abstract': "Can't seem to find any reason to get some sleep? This is why you should prioritize slumbering, according to science.", 'url': 'https://assets.msn.com/labs/mind/BBWGFdt.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48353}),
#  ConfigBox({'itemId': 'N25088', 'category': 'health', 'subcategory': 'wellness', 'title': 'What Is a Sleep Divorce and Should You Get One?', 'abstract': 'It might actually *help* your relationship.', 'url': 'https://assets.msn.com/labs/mind/BBWBzxs.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48382}),
#  ConfigBox({'itemId': 'N54274', 'category': 'health', 'subcategory': 'nutrition', 'title': 'This High Cholesterol Diet Plan Will Lower Your Cholesterol Numbers', 'abstract': 'Looking to lower your bad cholesterol and increase the good cholesterol in your blood? This high cholesterol diet plan will help keep your numbers low.', 'url': 'https://assets.msn.com/labs/mind/BBWqy1w.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48388}),
#  ConfigBox({'itemId': 'N64197', 'category': 'health', 'subcategory': 'pregnancyparenting', 'title': 'Temporary restraining order protects 9-month-old baby from being taken off life support', 'abstract': 'Update 4:33 p.m. Sunday with information about the temporary restraining order being granted. The family of 9-month-old Tinslee Lewis has been granted a temporary restraining order that will prevent the baby from being taken off life support Sunday. According to a family spokesperson, the restraining order was issued Sunday afternoon by a Tarrant County Judge. Nine-month-old Tinslee Lewis was going to be taken off life support against her...', 'url': 'https://assets.msn.com/labs/mind/BBWy9wj.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48440}),
#  ConfigBox({'itemId': 'N45312', 'category': 'health', 'subcategory': 'medical', 'title': 'The flu is ramping up in Maryland and West Virginia', 'abstract': 'Flu activity has slowly picked up in the region. It has now become widespread in Maryland, according to weekly flu monitoring data. In a Maryland flu monitoring report, more than 230 lab tests came back positive for the flu so far this season. Health providers reported more than 8,000 visits to clinics and emergency rooms with influenza like illness (ILI) complaints. Most of the patients range in age from infant to 24-years-old. The report also...', 'url': 'https://assets.msn.com/labs/mind/BBWyAP0.html', 'title_entities': '[{"Label": "Maryland", "Type": "G", "WikidataId": "Q1391", "Confidence": 1.0, "OccurrenceOffsets": [25], "SurfaceForms": ["Maryland"]}, {"Label": "West Virginia", "Type": "P", "WikidataId": "Q1371", "Confidence": 1.0, "OccurrenceOffsets": [38], "SurfaceForms": ["West Virginia"]}]', 'abstract_entities': '[{"Label": "Influenza", "Type": "C", "WikidataId": "Q2840", "Confidence": 0.994, "OccurrenceOffsets": [0], "SurfaceForms": ["Flu"]}, {"Label": "Maryland", "Type": "G", "WikidataId": "Q1391", "Confidence": 1.0, "OccurrenceOffsets": [81, 137], "SurfaceForms": ["Maryland", "Maryland"]}]', 'news_id': 48505}),
#  ConfigBox({'itemId': 'N17095', 'category': 'health', 'subcategory': 'pregnancyparenting', 'title': "Life Versus Law: A North Texas Mother's Fight As Hospital Plans To Take Baby Off Life Support", 'abstract': 'Nine-month-old Tinslee Lewis has never seen the outside of a hospital, and her mother is afraid she will never have that opportunity.', 'url': 'https://assets.msn.com/labs/mind/BBWyAtz.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48556}),
#  ConfigBox({'itemId': 'N25758', 'category': 'health', 'subcategory': 'medical', 'title': "When's The Best Time To Drink Milk?", 'abstract': "Here's the recommended time to best consume milk, according to experts.", 'url': 'https://assets.msn.com/labs/mind/BBWC23e.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 48607}),
#  ConfigBox({'itemId': 'N42480', 'category': 'health', 'subcategory': 'wellness', 'title': '4-year-old Iowan to face her 43rd surgery', 'abstract': 'Nadia Grimes, 4, has had time on her side. At 16 months old, she was diagnosed with a vascular ring, an abnormal formation of the aorta. The congenital heart problem led to a series of surgeries. Sign up for our Newsletters Last year, she took a trip to Disney with the help of the Make-A-Wish Foundation. "She is doing really well right now," said Christina Grimes, Nadia\'s mom. "The last surgery they did, they put a balloon catheter in to open up...', 'url': 'https://assets.msn.com/labs/mind/BBWyBur.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Make-A-Wish Foundation", "Type": "O", "WikidataId": "Q1192980", "Confidence": 1.0, "OccurrenceOffsets": [282], "SurfaceForms": ["Make-A-Wish Foundation"]}, {"Label": "The Walt Disney Company", "Type": "O", "WikidataId": "Q7414", "Confidence": 0.921, "OccurrenceOffsets": [254], "SurfaceForms": ["Disney"]}]', 'news_id': 48655}),
#  ConfigBox({'itemId': 'N14537', 'category': 'health', 'subcategory': 'wellness', 'title': 'Inside the treatment that is helping a boy who nearly drowned', 'abstract': nan, 'url': 'https://assets.msn.com/labs/mind/BBWCrfO.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 49390}),
#  ConfigBox({'itemId': 'N19257', 'category': 'health', 'subcategory': 'wellness', 'title': 'Sea Salt Health Benefits And Potential Downsides', 'abstract': 'Sea salt has the same amount of sodium chloride as regular table salt.', 'url': 'https://assets.msn.com/labs/mind/BBWIxy7.html', 'title_entities': '[{"Label": "Sea salt", "Type": "C", "WikidataId": "Q111837", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Sea Salt"]}, {"Label": "Health effects of wine", "Type": "C", "WikidataId": "Q4116329", "Confidence": 0.962, "OccurrenceOffsets": [9], "SurfaceForms": ["Health Benefits"]}]', 'abstract_entities': '[{"Label": "Sea salt", "Type": "C", "WikidataId": "Q111837", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Sea salt"]}]', 'news_id': 49596}),
#  ConfigBox({'itemId': 'N1767', 'category': 'health', 'subcategory': 'nutrition', 'title': 'French Pastry Diet For Weight Loss: Does It Work?', 'abstract': "Can French culture help America's obesity problem?", 'url': 'https://assets.msn.com/labs/mind/BBWD4fQ.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Culture of France", "Type": "U", "WikidataId": "Q1985804", "Confidence": 1.0, "OccurrenceOffsets": [4], "SurfaceForms": ["French culture"]}, {"Label": "United States", "Type": "G", "WikidataId": "Q30", "Confidence": 0.981, "OccurrenceOffsets": [24], "SurfaceForms": ["America"]}]', 'news_id': 49744}),
#  ConfigBox({'itemId': 'N56368', 'category': 'health', 'subcategory': 'wellness', 'title': 'Pediatric doctor, UT professor dies from medical issue while racing', 'abstract': 'A pediatric doctor at Dell Children\'s Medical Center died Sunday in Florida while driving in a race, according to the motor sport news website Racer. Timothy "Tim" George suffered a medical issue during the race and drove his vehicle to a pit lane where he was attended to by medical staff, Racer reported. He was later transported to a hospital in Sebring, Fla. where he died. He was 59 years ...', 'url': 'https://assets.msn.com/labs/mind/BBWyTwE.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Florida", "Type": "G", "WikidataId": "Q812", "Confidence": 0.989, "OccurrenceOffsets": [68, 358], "SurfaceForms": ["Florida", "Fla"]}, {"Label": "Dell Children\'s Medical Center of Central Texas", "Type": "F", "WikidataId": "Q24886189", "Confidence": 1.0, "OccurrenceOffsets": [22], "SurfaceForms": ["Dell Children\'s Medical Center"]}]', 'news_id': 49940}),
#  ConfigBox({'itemId': 'N19270', 'category': 'health', 'subcategory': 'health-news', 'title': "Is man's best friend the key to battling cancer?", 'abstract': "Healthy canines are being sought to participate in a study that may benefit man and man's best friend alike.", 'url': 'https://assets.msn.com/labs/mind/BBWDMq0.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Health", "Type": "C", "WikidataId": "Q12147", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Healthy"]}]', 'news_id': 49981}),
#  ConfigBox({'itemId': 'N47101', 'category': 'health', 'subcategory': 'health-news', 'title': 'Exercising More Past 60 Cuts Risk Of Stroke, Heart Disease', 'abstract': 'The elderly are supposed to exercise more if they want to live longer, according to a new study.', 'url': 'https://assets.msn.com/labs/mind/BBWsG9y.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 49990}),
#  ConfigBox({'itemId': 'N15948', 'category': 'health', 'subcategory': 'medical', 'title': 'This Is Your Body On The Flu', 'abstract': "Flu experts share what happens once you're exposed to the flu including why it triggers some of those unpleasant symptoms.", 'url': 'https://assets.msn.com/labs/mind/BBWDSMM.html', 'title_entities': '[{"Label": "Influenza", "Type": "C", "WikidataId": "Q2840", "Confidence": 0.987, "OccurrenceOffsets": [21], "SurfaceForms": ["The Flu"]}]', 'abstract_entities': '[{"Label": "Influenza", "Type": "C", "WikidataId": "Q2840", "Confidence": 0.987, "OccurrenceOffsets": [54], "SurfaceForms": ["the flu"]}]', 'news_id': 50107}),
#  ConfigBox({'itemId': 'N926', 'category': 'health', 'subcategory': 'wellness', 'title': "What Menopause Does to Women's Brains", 'abstract': "Two-thirds of Alzheimer's patients are women. My foggy 53-year-old brain could help explain why.", 'url': 'https://assets.msn.com/labs/mind/BBWsRpz.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "Alzheimer\'s disease", "Type": "U", "WikidataId": "Q11081", "Confidence": 1.0, "OccurrenceOffsets": [14], "SurfaceForms": ["Alzheimer\'s"]}, {"Label": "Supermajority", "Type": "C", "WikidataId": "Q1362323", "Confidence": 0.932, "OccurrenceOffsets": [0], "SurfaceForms": ["Two-thirds"]}]', 'news_id': 50351}),
#  ConfigBox({'itemId': 'N61648', 'category': 'health', 'subcategory': 'medical', 'title': '13 Unexpected Reasons Why You Might Have A Fever', 'abstract': "Feeling a little heated? It's typically nothing to worry about ― especially if you're sick. However, other issues can cause your temperature to rise.", 'url': 'https://assets.msn.com/labs/mind/BBWyfsu.html', 'title_entities': '[]', 'abstract_entities': '[]', 'news_id': 50497}),
#  ConfigBox({'itemId': 'N16016', 'category': 'health', 'subcategory': 'healthnews', 'title': 'More than 130,000 pounds of ground beef recalled for possible plastic contamination', 'abstract': "About 130,464 pounds of raw ground beef products have been recalled because they may contain plastic, the US Department of Agriculture's Food Safety and Inspection Service (FSIS) announced Thursday.", 'url': 'https://assets.msn.com/labs/mind/BBWsnTh.html', 'title_entities': '[{"Label": "Ground beef", "Type": "U", "WikidataId": "Q3408258", "Confidence": 1.0, "OccurrenceOffsets": [28], "SurfaceForms": ["ground beef"]}]', 'abstract_entities': '[{"Label": "Ground beef", "Type": "U", "WikidataId": "Q3408258", "Confidence": 1.0, "OccurrenceOffsets": [28], "SurfaceForms": ["ground beef"]}, {"Label": "Food Safety and Inspection Service", "Type": "O", "WikidataId": "Q5465387", "Confidence": 1.0, "OccurrenceOffsets": [137, 173], "SurfaceForms": ["Food Safety and Inspection Service", "FSIS"]}, {"Label": "United States Department of Agriculture", "Type": "O", "WikidataId": "Q501542", "Confidence": 1.0, "OccurrenceOffsets": [106], "SurfaceForms": ["US Department of Agriculture"]}]', 'news_id': 50721}),
#  ConfigBox({'itemId': 'N4396', 'category': 'health', 'subcategory': 'medical', 'title': "New CA Hospital Safety Ratings Released: 2 Get 'F' Grade", 'abstract': 'New hospital safety grades for California have been released. Two in the state got an F. See the full rankings here:', 'url': 'https://assets.msn.com/labs/mind/BBWym6J.html', 'title_entities': '[]', 'abstract_entities': '[{"Label": "California", "Type": "G", "WikidataId": "Q99", "Confidence": 0.998, "OccurrenceOffsets": [31], "SurfaceForms": ["California"]}]', 'news_id': 50784}),
#  ConfigBox({'itemId': 'N28170', 'category': 'health', 'subcategory': 'medical', 'title': 'Virginia, DC Hospital Safety Grades For 2019', 'abstract': 'The nonprofit Leapfrog group released its bi-annual round of hospital safety grades. See how your hospital in Virginia and DC scored.', 'url': 'https://assets.msn.com/labs/mind/BBWyqIz.html', 'title_entities': '[{"Label": "Virginia", "Type": "G", "WikidataId": "Q1370", "Confidence": 1.0, "OccurrenceOffsets": [0], "SurfaceForms": ["Virginia"]}]', 'abstract_entities': '[{"Label": "Patient safety organization", "Type": "O", "WikidataId": "Q7144999", "Confidence": 1.0, "OccurrenceOffsets": [14], "SurfaceForms": ["Leapfrog group"]}, {"Label": "Virginia", "Type": "G", "WikidataId": "Q1370", "Confidence": 1.0, "OccurrenceOffsets": [110], "SurfaceForms": ["Virginia"]}]', 'news_id': 50925})]
